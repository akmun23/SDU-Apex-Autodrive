# %% [markdown]
# # Run `tune_realistic_v2.py`
#
# This notebook launches the MPC tuner script from the local `MPC` folder and streams live logs.
#
# Steps:
# 1. Run the setup cell.
# 2. Edit arguments in the config cell.
# 3. Run the execution cell.
# 4. Inspect the latest CSV files.

# %%
from pathlib import Path
import subprocess
import sys
import os

REPO_ROOT = Path.cwd().resolve().parent.parent  # assumes notebook under MPC/test
MPC_DIR = REPO_ROOT / "MPC"
SCRIPT_PATH = MPC_DIR / "test" / "tune_realistic_v2.py"

print("REPO_ROOT:", REPO_ROOT)
print("MPC_DIR:", MPC_DIR)
print("SCRIPT_PATH exists:", SCRIPT_PATH.exists())
assert SCRIPT_PATH.exists(), f"Missing script: {SCRIPT_PATH}"
# Out:
# REPO_ROOT: /home/akselmo/Documents/GitHub/BachelorProject
# MPC_DIR: /home/akselmo/Documents/GitHub/BachelorProject/MPC
# SCRIPT_PATH exists: True

# %%
# Edit these args as needed.
RUN_ARGS = [
    "--jobs", "15",
    "--with-obstacles",
    "--phase2-top", "1",
    "--global-passes", "4",
]

COMMAND = [sys.executable, str(SCRIPT_PATH)] + RUN_ARGS
print("Command:", " ".join(COMMAND))
# Out:
# Command: /home/akselmo/Documents/GitHub/BachelorProject/.venv/bin/python /home/akselmo/Documents/GitHub/BachelorProject/MPC/test/tune_realistic_v2.py --jobs 15 --with-obstacles --phase2-top 1 --global-passes 4

# %%
# Run and stream logs live.
process = subprocess.Popen(
    COMMAND,
    cwd=str(MPC_DIR),
    stdout=subprocess.PIPE,
    stderr=subprocess.STDOUT,
    text=True,
    bufsize=1,
)

try:
    assert process.stdout is not None
    for line in process.stdout:
        print(line, end="")
finally:
    rc = process.wait()

print("\nReturn code:", rc)
# Out:
# ================================================================================
# MPC Weight Tuning - Hardware Map
# ================================================================================
#   Workers:     15
#   Mode:        hardware-matched only
#   Phase2->P4:  top 1
#   Global passes (P6-P8): 4
#   Obstacles:   on
#   Local sweep: off
#   Resume:      off
#   Base seed:   46123/52500 L=20352.0+H=248.864+V=60.0+LV=6.4+Y=1.56+RS=1.92 (score=10.643464, phase=Phase 2: Primary grid (Q_LAT x Q_HDG x Q_VEL x Q_LAT_VEL x Q_YAW x R_STEER x MPC_W_DELTA_ACTUAL), src=/home/akselmo/Downloads/tuning_hardware_base_20260425_161330.csv)
#   Solver mode: fixed H=20, DT=0.030; RHO/RHO_U tuned only in Phases 6-8
#   Config eval: single (one config must pass all 3 scenarios)
#   Base solver tuple: RHO=28.0 RHO_U=42.0 TOL=0.05 MAX_ITER=100
#   Wall margin: 0.140
#   Phase7 random: 2000
#   Phase8 random: 2000
#   Horizon sweep: [20]
#   Raceline:    /home/akselmo/Documents/GitHub/BachelorProject/MPC/trajectories/my_track_raceline.csv
#   Raceline tag:my_track
#   Track length:40.483 m
#   Scenario race         weight=0.50 dur= 75.0s lat=+0.00m v0= 0.0m/s line=my_track_base.csv
#   Scenario avoid_single weight=0.25 dur= 60.0s lat=+0.00m v0= 0.0m/s line=my_track_avoid_single.csv
#   Scenario avoid_double weight=0.25 dur= 60.0s lat=+0.00m v0= 0.0m/s line=my_track_avoid_double.csv
#
# Building test binary...
#   Build OK
#
# Running parameter effect sanity check...
#   All tested parameters show effect on output - OK
#   Results: test/tuning_hardware_base_20260505_112037.csv
#
#   Progress: test/tuning_hardware_base_20260505_112037_progress.txt
#
#
# ================================================================================
# Phase 1: One-at-a-time sensitivity - 72 configurations (15 workers)
# ================================================================================
#   [   1/72] 3/72 Q_LAT=120.0                                        FAIL  (ETA 29s)
#   [   2/72] 5/72 Q_LAT=200.0                                        FAIL  (ETA 16s)
#   [   3/72] 2/72 Q_LAT=80.0                                         FAIL  (ETA 16s)
#   [   4/72] 4/72 Q_LAT=160.0                                        FAIL  (ETA 13s)
#   [   5/72] 14/72 Q_HDG=14.0                                        FAIL  (ETA 14s)
#   [   6/72] 12/72 Q_HDG=10.0                                        FAIL  (ETA 12s)
#   [   7/72] 13/72 Q_HDG=12.0                                        FAIL  (ETA 10s)
#   [   8/72] 15/72 Q_HDG=16.0                                        FAIL  (ETA 9s)
#   [   9/72] 1/72 BASELINE                                           FAIL  (ETA 8s)
#   [  10/72] 17/72 Q_HDG=24.0                                        FAIL  (ETA 11s)
#   [  11/72] 18/72 Q_HDG=28.8                                        FAIL  (ETA 10s)
#   [  12/72] 16/72 Q_HDG=20.0                                        FAIL  (ETA 10s)
#   [  13/72] 6/72 Q_LAT=240.0                                        FAIL  (ETA 9s)
#   [  14/72] 19/72 Q_HDG=34.0                                        FAIL  (ETA 8s)
#   [  15/72] 20/72 Q_HDG=40.0                                        FAIL  (ETA 8s)
#   [  16/72] 21/72 Q_HDG=48.0                                        FAIL  (ETA 7s)
#   [  17/72] 24/72 Q_VEL=28.0                                        FAIL  (ETA 9s)
#   [  18/72] 28/72 Q_VEL=44.0                                        FAIL  (ETA 10s)
#   [  19/72] 25/72 Q_VEL=30.0                                        FAIL  (ETA 10s)
#   [  20/72] 22/72 Q_VEL=20.0                                        FAIL  (ETA 11s)
#   [  21/72] 27/72 Q_VEL=38.0                                        FAIL  (ETA 12s)
#   [  22/72] 30/72 Q_LAT_VEL=0.7                                     FAIL  (ETA 11s)
#   [  23/72] 23/72 Q_VEL=24.0                                        FAIL  (ETA 11s)
#   [  24/72] 29/72 Q_LAT_VEL=0.5                                     FAIL  (ETA 11s)
#   [  25/72] 32/72 Q_LAT_VEL=1.04                                    FAIL  (ETA 10s)
#   [  26/72] 7/72 Q_LAT=300.0                                        FAIL  (ETA 10s)
#   [  27/72] 8/72 Q_LAT=380.0                                        FAIL  (ETA 10s)
#   [  28/72] 9/72 Q_LAT=500.0                                        FAIL  (ETA 9s)
#   [  29/72] 10/72 Q_LAT=700.0                                       FAIL  (ETA 9s)
#   [  30/72] 37/72 Q_YAW=1.1                                         FAIL  (ETA 9s)
#   [  31/72] 38/72 Q_YAW=1.3                                         FAIL  (ETA 8s)
#   [  32/72] 11/72 Q_LAT=1000.0                                      FAIL  (ETA 8s)
#   [  33/72] 40/72 Q_YAW=1.7                                         FAIL  (ETA 8s)
#   [  34/72] 41/72 Q_YAW=1.9                                         FAIL  (ETA 7s)
#   [  35/72] 33/72 Q_LAT_VEL=1.2                                     FAIL  (ETA 7s)
#   [  36/72] 43/72 R_STEER=0.9                                       FAIL  (ETA 7s)
#   [  37/72] 31/72 Q_LAT_VEL=0.9                                     FAIL  (ETA 7s)
#   [  38/72] 36/72 Q_YAW=0.9                                         FAIL  (ETA 6s)
#   [  39/72] 34/72 Q_LAT_VEL=1.4                                     FAIL  (ETA 6s)
#   [  40/72] 26/72 Q_VEL=34.0                                        FAIL  (ETA 7s)
#   [  41/72] 35/72 Q_LAT_VEL=1.7                                     FAIL  (ETA 6s)
#   [  42/72] 47/72 R_STEER=1.7                                       FAIL  (ETA 6s)
#   [  43/72] 45/72 R_STEER=1.3                                       FAIL  (ETA 6s)
#   [  44/72] 50/72 R_ACCEL=0.006                                     FAIL  (ETA 6s)
#   [  45/72] 44/72 R_STEER=1.1                                       FAIL  (ETA 5s)
#   [  46/72] 53/72 R_ACCEL=0.012                                     FAIL  (ETA 5s)
#   [  47/72] 52/72 R_ACCEL=0.01                                      FAIL  (ETA 5s)
#   [  48/72] 58/72 W_JERK=0.05                                       FAIL  (ETA 5s)
#   [  49/72] 57/72 W_JERK=0.04                                       FAIL  (ETA 5s)
#   [  50/72] 59/72 W_JERK=0.065                                      FAIL  (ETA 4s)
#   [  51/72] 49/72 R_STEER=2.2                                       FAIL  (ETA 4s)
#   [  52/72] 48/72 R_STEER=1.9                                       FAIL  (ETA 4s)
#   [  53/72] 65/72 MPC_W_DELTA_ACTUAL=0.018                          FAIL  (ETA 4s)
#   [  54/72] 39/72 Q_YAW=1.5                                         FAIL  (ETA 4s)
#   [  55/72] 42/72 Q_YAW=2.2                                         FAIL  (ETA 3s)
#   [  56/72] 62/72 W_ACCEL_RATE=0.1                                  FAIL  (ETA 3s)
#   [  57/72] 60/72 W_ACCEL_RATE=0.06                                 FAIL  (ETA 3s)
#   [  58/72] 66/72 MPC_W_DELTA_ACTUAL=0.02                           FAIL  (ETA 3s)
#   [  59/72] 64/72 W_ACCEL_RATE=0.15                                 FAIL  (ETA 3s)
#   [  60/72] 55/72 W_JERK=0.02                                       FAIL  (ETA 2s)
#   [  61/72] 67/72 MPC_W_DELTA_ACTUAL=0.023                          FAIL  (ETA 2s)
#   [  62/72] 51/72 R_ACCEL=0.008                                     FAIL  (ETA 2s)
#   [  63/72] 54/72 R_ACCEL=0.015                                     FAIL  (ETA 2s)
#   [  64/72] 69/72 MPC_W_DELTA_ACTUAL=0.03                           FAIL  (ETA 2s)
#   [  65/72] 46/72 R_STEER=1.5                                       FAIL  (ETA 1s)
#   [  66/72] 68/72 MPC_W_DELTA_ACTUAL=0.026                          FAIL  (ETA 1s)
#   [  67/72] 61/72 W_ACCEL_RATE=0.08                                 FAIL  (ETA 1s)
#   [  68/72] 63/72 W_ACCEL_RATE=0.12                                 FAIL  (ETA 1s)
#   [  69/72] 72/72 TOL=0.01                                          FAIL  (ETA 1s)
#   [  70/72] 70/72 RHO=8.0                                           FAIL  (ETA 0s)
#   [  71/72] 71/72 RHO_U=24.0                                        FAIL  (ETA 0s)
#   [  72/72] 56/72 W_JERK=0.03                                       FAIL  (ETA 0s)
#
#   Phase 2 will test 50,000 configurations
#
# ================================================================================
# Phase 2: Primary grid (Q_LAT x Q_HDG x Q_VEL x Q_LAT_VEL x Q_YAW x R_STEER x MPC_W_DELTA_ACTUAL) - 50000 configurations (15 workers)
# ================================================================================
#   [   1/50000] 3/50000 L=600.0+H=10+V=20+LV=0.5+Y=1.0+RS=1.0+WDA=0.025+HZ=20+DT=0.030+CFG FAIL  (ETA 830228s)
#   [   2/50000] 6/50000 L=600.0+H=10+V=20+LV=0.5+Y=1.0+RS=1.25+WDA=0.02+HZ=20+DT=0.030+CFG FAIL  (ETA 416069s)
#   [   3/50000] 15/50000 L=600.0+H=10+V=20+LV=0.5+Y=1.0+RS=1.75+WDA=0.025+HZ=20+DT=0.030+CFG FAIL  (ETA 278226s)
#   [   4/50000] 10/50000 L=600.0+H=10+V=20+LV=0.5+Y=1.0+RS=1.5+WDA=0.02+HZ=20+DT=0.030+CFG FAIL  (ETA 216625s)
#   [   5/50000] 11/50000 L=600.0+H=10+V=20+LV=0.5+Y=1.0+RS=1.5+WDA=0.025+HZ=20+DT=0.030+CFG FAIL  (ETA 173578s)
#   [   6/50000] 13/50000 L=600.0+H=10+V=20+LV=0.5+Y=1.0+RS=1.75+WDA=0.015+HZ=20+DT=0.030+CFG FAIL  (ETA 146202s)
#   [   7/50000] 14/50000 L=600.0+H=10+V=20+LV=0.5+Y=1.0+RS=1.75+WDA=0.02+HZ=20+DT=0.030+CFG FAIL  (ETA 126573s)
#   [   8/50000] 7/50000 L=600.0+H=10+V=20+LV=0.5+Y=1.0+RS=1.25+WDA=0.025+HZ=20+DT=0.030+CFG FAIL  (ETA 110760s)
#   [   9/50000] 12/50000 L=600.0+H=10+V=20+LV=0.5+Y=1.0+RS=1.5+WDA=0.03+HZ=20+DT=0.030+CFG FAIL  (ETA 98865s)
#   [  10/50000] 8/50000 L=600.0+H=10+V=20+LV=0.5+Y=1.0+RS=1.25+WDA=0.03+HZ=20+DT=0.030+CFG FAIL  (ETA 90567s)
#   [  11/50000] 2/50000 L=600.0+H=10+V=20+LV=0.5+Y=1.0+RS=1.0+WDA=0.02+HZ=20+DT=0.030+CFG FAIL  (ETA 82801s)
#   [  12/50000] 17/50000 L=600.0+H=10+V=20+LV=0.5+Y=1.0+RS=2.0+WDA=0.015+HZ=20+DT=0.030+CFG FAIL  (ETA 77200s)
#   [  13/50000] 1/50000 L=600.0+H=10+V=20+LV=0.5+Y=1.0+RS=1.0+WDA=0.015+HZ=20+DT=0.030+CFG FAIL  (ETA 71626s)
#   [  14/50000] 18/50000 L=600.0+H=10+V=20+LV=0.5+Y=1.0+RS=2.0+WDA=0.02+HZ=20+DT=0.030+CFG FAIL  (ETA 66722s)
#   [  15/50000] 4/50000 L=600.0+H=10+V=20+LV=0.5+Y=1.0+RS=1.0+WDA=0.03+HZ=20+DT=0.030+CFG FAIL  (ETA 62621s)
#   [  16/50000] 5/50000 L=600.0+H=10+V=20+LV=0.5+Y=1.0+RS=1.25+WDA=0.015+HZ=20+DT=0.030+CFG FAIL  (ETA 58774s)
#   [  17/50000] 9/50000 L=600.0+H=10+V=20+LV=0.5+Y=1.0+RS=1.5+WDA=0.015+HZ=20+DT=0.030+CFG FAIL  (ETA 55540s)
#   [  18/50000] 22/50000 L=600.0+H=10+V=20+LV=0.5+Y=1.25+RS=1.0+WDA=0.02+HZ=20+DT=0.030+CFG FAIL  (ETA 53790s)
#   [  19/50000] 20/50000 L=600.0+H=10+V=20+LV=0.5+Y=1.0+RS=2.0+WDA=0.03+HZ=20+DT=0.030+CFG FAIL  (ETA 51179s)
#   [  20/50000] 19/50000 L=600.0+H=10+V=20+LV=0.5+Y=1.0+RS=2.0+WDA=0.025+HZ=20+DT=0.030+CFG FAIL  (ETA 48934s)
#   [  21/50000] 24/50000 L=600.0+H=10+V=20+LV=0.5+Y=1.25+RS=1.0+WDA=0.03+HZ=20+DT=0.030+CFG FAIL  (ETA 46879s)
#   [  22/50000] 25/50000 L=600.0+H=10+V=20+LV=0.5+Y=1.25+RS=1.25+WDA=0.015+HZ=20+DT=0.030+CFG FAIL  (ETA 44965s)
#   [  23/50000] 21/50000 L=600.0+H=10+V=20+LV=0.5+Y=1.25+RS=1.0+WDA=0.015+HZ=20+DT=0.030+CFG FAIL  (ETA 43073s)
#   [  24/50000] 29/50000 L=600.0+H=10+V=20+LV=0.5+Y=1.25+RS=1.5+WDA=0.015+HZ=20+DT=0.030+CFG FAIL  (ETA 41639s)
#   [  25/50000] 26/50000 L=600.0+H=10+V=20+LV=0.5+Y=1.25+RS=1.25+WDA=0.02+HZ=20+DT=0.030+CFG FAIL  (ETA 40097s)
#   [  26/50000] 27/50000 L=600.0+H=10+V=20+LV=0.5+Y=1.25+RS=1.25+WDA=0.025+HZ=20+DT=0.030+CFG FAIL  (ETA 38991s)
#   [  27/50000] 23/50000 L=600.0+H=10+V=20+LV=0.5+Y=1.25+RS=1.0+WDA=0.025+HZ=20+DT=0.030+CFG FAIL  (ETA 37590s)
#   [  28/50000] 28/50000 L=600.0+H=10+V=20+LV=0.5+Y=1.25+RS=1.25+WDA=0.03+HZ=20+DT=0.030+CFG FAIL  (ETA 36465s)
#   [  29/50000] 30/50000 L=600.0+H=10+V=20+LV=0.5+Y=1.25+RS=1.5+WDA=0.02+HZ=20+DT=0.030+CFG FAIL  (ETA 35286s)
#   [  30/50000] 16/50000 L=600.0+H=10+V=20+LV=0.5+Y=1.0+RS=1.75+WDA=0.03+HZ=20+DT=0.030+CFG FAIL  (ETA 34593s)
#   [  31/50000] 31/50000 L=600.0+H=10+V=20+LV=0.5+Y=1.25+RS=1.5+WDA=0.025+HZ=20+DT=0.030+CFG FAIL  (ETA 34032s)
#   [  32/50000] 32/50000 L=600.0+H=10+V=20+LV=0.5+Y=1.25+RS=1.5+WDA=0.03+HZ=20+DT=0.030+CFG FAIL  (ETA 33321s)
#   [  33/50000] 37/50000 L=600.0+H=10+V=20+LV=0.5+Y=1.25+RS=2.0+WDA=0.015+HZ=20+DT=0.030+CFG FAIL  (ETA 32350s)
#   [  34/50000] 35/50000 L=600.0+H=10+V=20+LV=0.5+Y=1.25+RS=1.75+WDA=0.025+HZ=20+DT=0.030+CFG FAIL  (ETA 31546s)
#   [  35/50000] 38/50000 L=600.0+H=10+V=20+LV=0.5+Y=1.25+RS=2.0+WDA=0.02+HZ=20+DT=0.030+CFG FAIL  (ETA 30817s)
#   [  36/50000] 36/50000 L=600.0+H=10+V=20+LV=0.5+Y=1.25+RS=1.75+WDA=0.03+HZ=20+DT=0.030+CFG FAIL  (ETA 30105s)
#   [  37/50000] 34/50000 L=600.0+H=10+V=20+LV=0.5+Y=1.25+RS=1.75+WDA=0.02+HZ=20+DT=0.030+CFG FAIL  (ETA 29453s)
#   [  38/50000] 40/50000 L=600.0+H=10+V=20+LV=0.5+Y=1.25+RS=2.0+WDA=0.03+HZ=20+DT=0.030+CFG FAIL  (ETA 28832s)
#   [  39/50000] 44/50000 L=600.0+H=10+V=20+LV=0.5+Y=1.5+RS=1.0+WDA=0.03+HZ=20+DT=0.030+CFG FAIL  (ETA 28445s)
#   [  40/50000] 33/50000 L=600.0+H=10+V=20+LV=0.5+Y=1.25+RS=1.75+WDA=0.015+HZ=20+DT=0.030+CFG FAIL  (ETA 27844s)
#   [  41/50000] 46/50000 L=600.0+H=10+V=20+LV=0.5+Y=1.5+RS=1.25+WDA=0.02+HZ=20+DT=0.030+CFG FAIL  (ETA 27210s)
#   [  42/50000] 41/50000 L=600.0+H=10+V=20+LV=0.5+Y=1.5+RS=1.0+WDA=0.015+HZ=20+DT=0.030+CFG FAIL  (ETA 27098s)
#   [  43/50000] 50/50000 L=600.0+H=10+V=20+LV=0.5+Y=1.5+RS=1.5+WDA=0.02+HZ=20+DT=0.030+CFG FAIL  (ETA 26523s)
#   [  44/50000] 42/50000 L=600.0+H=10+V=20+LV=0.5+Y=1.5+RS=1.0+WDA=0.02+HZ=20+DT=0.030+CFG FAIL  (ETA 26221s)
#   [  45/50000] 39/50000 L=600.0+H=10+V=20+LV=0.5+Y=1.25+RS=2.0+WDA=0.025+HZ=20+DT=0.030+CFG FAIL  (ETA 25707s)
#   [  46/50000] 52/50000 L=600.0+H=10+V=20+LV=0.5+Y=1.5+RS=1.5+WDA=0.03+HZ=20+DT=0.030+CFG FAIL  (ETA 25176s)
#   [  47/50000] 53/50000 L=600.0+H=10+V=20+LV=0.5+Y=1.5+RS=1.75+WDA=0.015+HZ=20+DT=0.030+CFG FAIL  (ETA 24672s)
#   [  48/50000] 48/50000 L=600.0+H=10+V=20+LV=0.5+Y=1.5+RS=1.25+WDA=0.03+HZ=20+DT=0.030+CFG FAIL  (ETA 24188s)
#   [  49/50000] 43/50000 L=600.0+H=10+V=20+LV=0.5+Y=1.5+RS=1.0+WDA=0.025+HZ=20+DT=0.030+CFG FAIL  (ETA 23897s)
#   [  50/50000] 45/50000 L=600.0+H=10+V=20+LV=0.5+Y=1.5+RS=1.25+WDA=0.015+HZ=20+DT=0.030+CFG FAIL  (ETA 23464s)
#   [  51/50000] 51/50000 L=600.0+H=10+V=20+LV=0.5+Y=1.5+RS=1.5+WDA=0.025+HZ=20+DT=0.030+CFG FAIL  (ETA 23016s)
#   [  52/50000] 56/50000 L=600.0+H=10+V=20+LV=0.5+Y=1.5+RS=1.75+WDA=0.03+HZ=20+DT=0.030+CFG FAIL  (ETA 22777s)
#   [  53/50000] 49/50000 L=600.0+H=10+V=20+LV=0.5+Y=1.5+RS=1.5+WDA=0.015+HZ=20+DT=0.030+CFG FAIL  (ETA 22539s)
#   [  54/50000] 61/50000 L=600.0+H=10+V=20+LV=0.5+Y=1.75+RS=1.0+WDA=0.015+HZ=20+DT=0.030+CFG FAIL  (ETA 22188s)
#   [  55/50000] 62/50000 L=600.0+H=10+V=20+LV=0.5+Y=1.75+RS=1.0+WDA=0.02+HZ=20+DT=0.030+CFG FAIL  (ETA 21827s)
#   [  56/50000] 63/50000 L=600.0+H=10+V=20+LV=0.5+Y=1.75+RS=1.0+WDA=0.025+HZ=20+DT=0.030+CFG FAIL  (ETA 21470s)
#   [  57/50000] 57/50000 L=600.0+H=10+V=20+LV=0.5+Y=1.5+RS=2.0+WDA=0.015+HZ=20+DT=0.030+CFG FAIL  (ETA 21188s)
#   [  58/50000] 64/50000 L=600.0+H=10+V=20+LV=0.5+Y=1.75+RS=1.0+WDA=0.03+HZ=20+DT=0.030+CFG FAIL  (ETA 20897s)
#   [  59/50000] 55/50000 L=600.0+H=10+V=20+LV=0.5+Y=1.5+RS=1.75+WDA=0.025+HZ=20+DT=0.030+CFG FAIL  (ETA 20603s)
#   [  60/50000] 47/50000 L=600.0+H=10+V=20+LV=0.5+Y=1.5+RS=1.25+WDA=0.025+HZ=20+DT=0.030+CFG FAIL  (ETA 20320s)
#   [  61/50000] 54/50000 L=600.0+H=10+V=20+LV=0.5+Y=1.5+RS=1.75+WDA=0.02+HZ=20+DT=0.030+CFG FAIL  (ETA 20017s)
#   [  62/50000] 66/50000 L=600.0+H=10+V=20+LV=0.5+Y=1.75+RS=1.25+WDA=0.02+HZ=20+DT=0.030+CFG FAIL  (ETA 20176s)
#   [  63/50000] 58/50000 L=600.0+H=10+V=20+LV=0.5+Y=1.5+RS=2.0+WDA=0.02+HZ=20+DT=0.030+CFG FAIL  (ETA 19885s)
#   [  64/50000] 68/50000 L=600.0+H=10+V=20+LV=0.5+Y=1.75+RS=1.25+WDA=0.03+HZ=20+DT=0.030+CFG FAIL  (ETA 19766s)
#   [  65/50000] 71/50000 L=600.0+H=10+V=20+LV=0.5+Y=1.75+RS=1.5+WDA=0.025+HZ=20+DT=0.030+CFG FAIL  (ETA 19529s)
#   [  66/50000] 59/50000 L=600.0+H=10+V=20+LV=0.5+Y=1.5+RS=2.0+WDA=0.025+HZ=20+DT=0.030+CFG FAIL  (ETA 19240s)
#   [  67/50000] 60/50000 L=600.0+H=10+V=20+LV=0.5+Y=1.5+RS=2.0+WDA=0.03+HZ=20+DT=0.030+CFG FAIL  (ETA 19036s)
#   [  68/50000] 67/50000 L=600.0+H=10+V=20+LV=0.5+Y=1.75+RS=1.25+WDA=0.025+HZ=20+DT=0.030+CFG FAIL  (ETA 18814s)
#   [  69/50000] 65/50000 L=600.0+H=10+V=20+LV=0.5+Y=1.75+RS=1.25+WDA=0.015+HZ=20+DT=0.030+CFG FAIL  (ETA 18654s)
#   [  70/50000] 75/50000 L=600.0+H=10+V=20+LV=0.5+Y=1.75+RS=1.75+WDA=0.025+HZ=20+DT=0.030+CFG FAIL  (ETA 18392s)
#   [  71/50000] 70/50000 L=600.0+H=10+V=20+LV=0.5+Y=1.75+RS=1.5+WDA=0.02+HZ=20+DT=0.030+CFG FAIL  (ETA 18181s)
#   [  72/50000] 69/50000 L=600.0+H=10+V=20+LV=0.5+Y=1.75+RS=1.5+WDA=0.015+HZ=20+DT=0.030+CFG FAIL  (ETA 18019s)
#   [  73/50000] 74/50000 L=600.0+H=10+V=20+LV=0.5+Y=1.75+RS=1.75+WDA=0.02+HZ=20+DT=0.030+CFG FAIL  (ETA 17899s)
#   [  74/50000] 76/50000 L=600.0+H=10+V=20+LV=0.5+Y=1.75+RS=1.75+WDA=0.03+HZ=20+DT=0.030+CFG FAIL  (ETA 17694s)
#   [  75/50000] 73/50000 L=600.0+H=10+V=20+LV=0.5+Y=1.75+RS=1.75+WDA=0.015+HZ=20+DT=0.030+CFG FAIL  (ETA 17477s)
#   [  76/50000] 72/50000 L=600.0+H=10+V=20+LV=0.5+Y=1.75+RS=1.5+WDA=0.03+HZ=20+DT=0.030+CFG FAIL  (ETA 17524s)
#   [  77/50000] 83/50000 L=600.0+H=10+V=20+LV=0.5+Y=2.0+RS=1.0+WDA=0.025+HZ=20+DT=0.030+CFG FAIL  (ETA 17509s)
#   [  78/50000] 84/50000 L=600.0+H=10+V=20+LV=0.5+Y=2.0+RS=1.0+WDA=0.03+HZ=20+DT=0.030+CFG FAIL  (ETA 17381s)
#   [  79/50000] 81/50000 L=600.0+H=10+V=20+LV=0.5+Y=2.0+RS=1.0+WDA=0.015+HZ=20+DT=0.030+CFG FAIL  (ETA 17191s)
#   [  80/50000] 79/50000 L=600.0+H=10+V=20+LV=0.5+Y=1.75+RS=2.0+WDA=0.025+HZ=20+DT=0.030+CFG FAIL  (ETA 17004s)
#   [  81/50000] 87/50000 L=600.0+H=10+V=20+LV=0.5+Y=2.0+RS=1.25+WDA=0.025+HZ=20+DT=0.030+CFG FAIL  (ETA 16813s)
#   [  82/50000] 80/50000 L=600.0+H=10+V=20+LV=0.5+Y=1.75+RS=2.0+WDA=0.03+HZ=20+DT=0.030+CFG FAIL  (ETA 16652s)
#   [  83/50000] 82/50000 L=600.0+H=10+V=20+LV=0.5+Y=2.0+RS=1.0+WDA=0.02+HZ=20+DT=0.030+CFG FAIL  (ETA 16452s)
#   [  84/50000] 89/50000 L=600.0+H=10+V=20+LV=0.5+Y=2.0+RS=1.5+WDA=0.015+HZ=20+DT=0.030+CFG FAIL  (ETA 16260s)
#   [  85/50000] 88/50000 L=600.0+H=10+V=20+LV=0.5+Y=2.0+RS=1.25+WDA=0.03+HZ=20+DT=0.030+CFG FAIL  (ETA 16271s)
#   [  86/50000] 86/50000 L=600.0+H=10+V=20+LV=0.5+Y=2.0+RS=1.25+WDA=0.02+HZ=20+DT=0.030+CFG FAIL  (ETA 16121s)
#   [  87/50000] 77/50000 L=600.0+H=10+V=20+LV=0.5+Y=1.75+RS=2.0+WDA=0.015+HZ=20+DT=0.030+CFG FAIL  (ETA 16121s)
#   [  88/50000] 78/50000 L=600.0+H=10+V=20+LV=0.5+Y=1.75+RS=2.0+WDA=0.02+HZ=20+DT=0.030+CFG FAIL  (ETA 16005s)
#   [  89/50000] 85/50000 L=600.0+H=10+V=20+LV=0.5+Y=2.0+RS=1.25+WDA=0.015+HZ=20+DT=0.030+CFG FAIL  (ETA 15910s)
#   [  90/50000] 94/50000 L=600.0+H=10+V=20+LV=0.5+Y=2.0+RS=1.75+WDA=0.02+HZ=20+DT=0.030+CFG FAIL  (ETA 15876s)
#   [  91/50000] 98/50000 L=600.0+H=10+V=20+LV=0.5+Y=2.0+RS=2.0+WDA=0.02+HZ=20+DT=0.030+CFG FAIL  (ETA 15785s)
#   [  92/50000] 90/50000 L=600.0+H=10+V=20+LV=0.5+Y=2.0+RS=1.5+WDA=0.02+HZ=20+DT=0.030+CFG FAIL  (ETA 15629s)
#   [  93/50000] 92/50000 L=600.0+H=10+V=20+LV=0.5+Y=2.0+RS=1.5+WDA=0.03+HZ=20+DT=0.030+CFG FAIL  (ETA 15560s)
#   [  94/50000] 93/50000 L=600.0+H=10+V=20+LV=0.5+Y=2.0+RS=1.75+WDA=0.015+HZ=20+DT=0.030+CFG FAIL  (ETA 15457s)
#   [  95/50000] 97/50000 L=600.0+H=10+V=20+LV=0.5+Y=2.0+RS=2.0+WDA=0.015+HZ=20+DT=0.030+CFG FAIL  (ETA 15396s)
#   [  96/50000] 91/50000 L=600.0+H=10+V=20+LV=0.5+Y=2.0+RS=1.5+WDA=0.025+HZ=20+DT=0.030+CFG FAIL  (ETA 15242s)
#   [  97/50000] 101/50000 L=600.0+H=10+V=20+LV=0.75+Y=1.0+RS=1.0+WDA=0.015+HZ=20+DT=0.030+CFG FAIL  (ETA 15086s)
#   [  98/50000] 100/50000 L=600.0+H=10+V=20+LV=0.5+Y=2.0+RS=2.0+WDA=0.03+HZ=20+DT=0.030+CFG FAIL  (ETA 15094s)
#   [  99/50000] 99/50000 L=600.0+H=10+V=20+LV=0.5+Y=2.0+RS=2.0+WDA=0.025+HZ=20+DT=0.030+CFG FAIL  (ETA 15028s)
#   [ 100/50000] 102/50000 L=600.0+H=10+V=20+LV=0.75+Y=1.0+RS=1.0+WDA=0.02+HZ=20+DT=0.030+CFG FAIL  (ETA 15084s)
#   [ 101/50000] 104/50000 L=600.0+H=10+V=20+LV=0.75+Y=1.0+RS=1.0+WDA=0.03+HZ=20+DT=0.030+CFG FAIL  (ETA 15011s)
#   [ 102/50000] 103/50000 L=600.0+H=10+V=20+LV=0.75+Y=1.0+RS=1.0+WDA=0.025+HZ=20+DT=0.030+CFG FAIL  (ETA 14874s)
#   [ 103/50000] 95/50000 L=600.0+H=10+V=20+LV=0.5+Y=2.0+RS=1.75+WDA=0.025+HZ=20+DT=0.030+CFG FAIL  (ETA 14759s)
#   [ 104/50000] 109/50000 L=600.0+H=10+V=20+LV=0.75+Y=1.0+RS=1.5+WDA=0.015+HZ=20+DT=0.030+CFG FAIL  (ETA 14751s)
#   [ 105/50000] 96/50000 L=600.0+H=10+V=20+LV=0.5+Y=2.0+RS=1.75+WDA=0.03+HZ=20+DT=0.030+CFG FAIL  (ETA 14619s)
#   [ 106/50000] 106/50000 L=600.0+H=10+V=20+LV=0.75+Y=1.0+RS=1.25+WDA=0.02+HZ=20+DT=0.030+CFG FAIL  (ETA 14524s)
#   [ 107/50000] 111/50000 L=600.0+H=10+V=20+LV=0.75+Y=1.0+RS=1.5+WDA=0.025+HZ=20+DT=0.030+CFG FAIL  (ETA 14482s)
#   [ 108/50000] 105/50000 L=600.0+H=10+V=20+LV=0.75+Y=1.0+RS=1.25+WDA=0.015+HZ=20+DT=0.030+CFG FAIL  (ETA 14443s)
#   [ 109/50000] 112/50000 L=600.0+H=10+V=20+LV=0.75+Y=1.0+RS=1.5+WDA=0.03+HZ=20+DT=0.030+CFG FAIL  (ETA 14400s)
#   [ 110/50000] 107/50000 L=600.0+H=10+V=20+LV=0.75+Y=1.0+RS=1.25+WDA=0.025+HZ=20+DT=0.030+CFG FAIL  (ETA 14366s)
#   [ 111/50000] 108/50000 L=600.0+H=10+V=20+LV=0.75+Y=1.0+RS=1.25+WDA=0.03+HZ=20+DT=0.030+CFG FAIL  (ETA 14264s)
#   [ 112/50000] 110/50000 L=600.0+H=10+V=20+LV=0.75+Y=1.0+RS=1.5+WDA=0.02+HZ=20+DT=0.030+CFG FAIL  (ETA 14186s)
#   [ 113/50000] 123/50000 L=600.0+H=10+V=20+LV=0.75+Y=1.25+RS=1.0+WDA=0.025+HZ=20+DT=0.030+CFG FAIL  (ETA 14395s)
#   [ 114/50000] 114/50000 L=600.0+H=10+V=20+LV=0.75+Y=1.0+RS=1.75+WDA=0.02+HZ=20+DT=0.030+CFG FAIL  (ETA 14271s)
#   [ 115/50000] 120/50000 L=600.0+H=10+V=20+LV=0.75+Y=1.0+RS=2.0+WDA=0.03+HZ=20+DT=0.030+CFG FAIL  (ETA 14204s)
#   [ 116/50000] 113/50000 L=600.0+H=10+V=20+LV=0.75+Y=1.0+RS=1.75+WDA=0.015+HZ=20+DT=0.030+CFG FAIL  (ETA 14093s)
#   [ 117/50000] 122/50000 L=600.0+H=10+V=20+LV=0.75+Y=1.25+RS=1.0+WDA=0.02+HZ=20+DT=0.030+CFG FAIL  (ETA 14027s)
#   [ 118/50000] 121/50000 L=600.0+H=10+V=20+LV=0.75+Y=1.25+RS=1.0+WDA=0.015+HZ=20+DT=0.030+CFG FAIL  (ETA 14061s)
#   [ 119/50000] 116/50000 L=600.0+H=10+V=20+LV=0.75+Y=1.0+RS=1.75+WDA=0.03+HZ=20+DT=0.030+CFG FAIL  (ETA 14202s)
#   [ 120/50000] 117/50000 L=600.0+H=10+V=20+LV=0.75+Y=1.0+RS=2.0+WDA=0.015+HZ=20+DT=0.030+CFG FAIL  (ETA 14129s)
#   [ 121/50000] 115/50000 L=600.0+H=10+V=20+LV=0.75+Y=1.0+RS=1.75+WDA=0.025+HZ=20+DT=0.030+CFG FAIL  (ETA 14127s)
#   [ 122/50000] 118/50000 L=600.0+H=10+V=20+LV=0.75+Y=1.0+RS=2.0+WDA=0.02+HZ=20+DT=0.030+CFG FAIL  (ETA 14100s)
#   [ 123/50000] 124/50000 L=600.0+H=10+V=20+LV=0.75+Y=1.25+RS=1.0+WDA=0.03+HZ=20+DT=0.030+CFG FAIL  (ETA 14062s)
#   [ 124/50000] 119/50000 L=600.0+H=10+V=20+LV=0.75+Y=1.0+RS=2.0+WDA=0.025+HZ=20+DT=0.030+CFG FAIL  (ETA 13976s)
#   [ 125/50000] 126/50000 L=600.0+H=10+V=20+LV=0.75+Y=1.25+RS=1.25+WDA=0.02+HZ=20+DT=0.030+CFG FAIL  (ETA 13889s)
#   [ 126/50000] 129/50000 L=600.0+H=10+V=20+LV=0.75+Y=1.25+RS=1.5+WDA=0.015+HZ=20+DT=0.030+CFG FAIL  (ETA 13816s)
#   [ 127/50000] 131/50000 L=600.0+H=10+V=20+LV=0.75+Y=1.25+RS=1.5+WDA=0.025+HZ=20+DT=0.030+CFG FAIL  (ETA 13770s)
#   [ 128/50000] 128/50000 L=600.0+H=10+V=20+LV=0.75+Y=1.25+RS=1.25+WDA=0.03+HZ=20+DT=0.030+CFG FAIL  (ETA 13671s)
#   [ 129/50000] 125/50000 L=600.0+H=10+V=20+LV=0.75+Y=1.25+RS=1.25+WDA=0.015+HZ=20+DT=0.030+CFG FAIL  (ETA 13578s)
#   [ 130/50000] 133/50000 L=600.0+H=10+V=20+LV=0.75+Y=1.25+RS=1.75+WDA=0.015+HZ=20+DT=0.030+CFG FAIL  (ETA 13490s)
#   [ 131/50000] 127/50000 L=600.0+H=10+V=20+LV=0.75+Y=1.25+RS=1.25+WDA=0.025+HZ=20+DT=0.030+CFG FAIL  (ETA 13409s)
#   [ 132/50000] 130/50000 L=600.0+H=10+V=20+LV=0.75+Y=1.25+RS=1.5+WDA=0.02+HZ=20+DT=0.030+CFG FAIL  (ETA 13511s)
#   [ 133/50000] 132/50000 L=600.0+H=10+V=20+LV=0.75+Y=1.25+RS=1.5+WDA=0.03+HZ=20+DT=0.030+CFG FAIL  (ETA 13496s)
#   [ 134/50000] 141/50000 L=600.0+H=10+V=20+LV=0.75+Y=1.5+RS=1.0+WDA=0.015+HZ=20+DT=0.030+CFG FAIL  (ETA 13410s)
#   [ 135/50000] 135/50000 L=600.0+H=10+V=20+LV=0.75+Y=1.25+RS=1.75+WDA=0.025+HZ=20+DT=0.030+CFG FAIL  (ETA 13361s)
#   [ 136/50000] 137/50000 L=600.0+H=10+V=20+LV=0.75+Y=1.25+RS=2.0+WDA=0.015+HZ=20+DT=0.030+CFG FAIL  (ETA 13334s)
#   [ 137/50000] 143/50000 L=600.0+H=10+V=20+LV=0.75+Y=1.5+RS=1.0+WDA=0.025+HZ=20+DT=0.030+CFG FAIL  (ETA 13243s)
#   [ 138/50000] 145/50000 L=600.0+H=10+V=20+LV=0.75+Y=1.5+RS=1.25+WDA=0.015+HZ=20+DT=0.030+CFG FAIL  (ETA 13175s)
#   [ 139/50000] 136/50000 L=600.0+H=10+V=20+LV=0.75+Y=1.25+RS=1.75+WDA=0.03+HZ=20+DT=0.030+CFG FAIL  (ETA 13097s)
#   [ 140/50000] 142/50000 L=600.0+H=10+V=20+LV=0.75+Y=1.5+RS=1.0+WDA=0.02+HZ=20+DT=0.030+CFG FAIL  (ETA 13096s)
#   [ 141/50000] 144/50000 L=600.0+H=10+V=20+LV=0.75+Y=1.5+RS=1.0+WDA=0.03+HZ=20+DT=0.030+CFG FAIL  (ETA 13078s)
#   [ 142/50000] 134/50000 L=600.0+H=10+V=20+LV=0.75+Y=1.25+RS=1.75+WDA=0.02+HZ=20+DT=0.030+CFG FAIL  (ETA 13035s)
#   [ 143/50000] 148/50000 L=600.0+H=10+V=20+LV=0.75+Y=1.5+RS=1.25+WDA=0.03+HZ=20+DT=0.030+CFG FAIL  (ETA 12989s)
#   [ 144/50000] 138/50000 L=600.0+H=10+V=20+LV=0.75+Y=1.25+RS=2.0+WDA=0.02+HZ=20+DT=0.030+CFG FAIL  (ETA 12955s)
#   [ 145/50000] 139/50000 L=600.0+H=10+V=20+LV=0.75+Y=1.25+RS=2.0+WDA=0.025+HZ=20+DT=0.030+CFG FAIL  (ETA 12993s)
#   [ 146/50000] 153/50000 L=600.0+H=10+V=20+LV=0.75+Y=1.5+RS=1.75+WDA=0.015+HZ=20+DT=0.030+CFG FAIL  (ETA 12956s)
#   [ 147/50000] 154/50000 L=600.0+H=10+V=20+LV=0.75+Y=1.5+RS=1.75+WDA=0.02+HZ=20+DT=0.030+CFG FAIL  (ETA 12892s)
#   [ 148/50000] 147/50000 L=600.0+H=10+V=20+LV=0.75+Y=1.5+RS=1.25+WDA=0.025+HZ=20+DT=0.030+CFG FAIL  (ETA 12864s)
#   [ 149/50000] 152/50000 L=600.0+H=10+V=20+LV=0.75+Y=1.5+RS=1.5+WDA=0.03+HZ=20+DT=0.030+CFG FAIL  (ETA 12792s)
#   [ 150/50000] 146/50000 L=600.0+H=10+V=20+LV=0.75+Y=1.5+RS=1.25+WDA=0.02+HZ=20+DT=0.030+CFG FAIL  (ETA 12731s)
#   [ 151/50000] 140/50000 L=600.0+H=10+V=20+LV=0.75+Y=1.25+RS=2.0+WDA=0.03+HZ=20+DT=0.030+CFG FAIL  (ETA 12764s)
#   [ 152/50000] 157/50000 L=600.0+H=10+V=20+LV=0.75+Y=1.5+RS=2.0+WDA=0.015+HZ=20+DT=0.030+CFG FAIL  (ETA 12723s)
#   [ 153/50000] 151/50000 L=600.0+H=10+V=20+LV=0.75+Y=1.5+RS=1.5+WDA=0.025+HZ=20+DT=0.030+CFG FAIL  (ETA 12644s)
#   [ 154/50000] 160/50000 L=600.0+H=10+V=20+LV=0.75+Y=1.5+RS=2.0+WDA=0.03+HZ=20+DT=0.030+CFG FAIL  (ETA 12622s)
#   [ 155/50000] 149/50000 L=600.0+H=10+V=20+LV=0.75+Y=1.5+RS=1.5+WDA=0.015+HZ=20+DT=0.030+CFG FAIL  (ETA 12606s)
#   [ 156/50000] 159/50000 L=600.0+H=10+V=20+LV=0.75+Y=1.5+RS=2.0+WDA=0.025+HZ=20+DT=0.030+CFG FAIL  (ETA 12589s)
#   [ 157/50000] 158/50000 L=600.0+H=10+V=20+LV=0.75+Y=1.5+RS=2.0+WDA=0.02+HZ=20+DT=0.030+CFG FAIL  (ETA 12543s)
#   [ 158/50000] 150/50000 L=600.0+H=10+V=20+LV=0.75+Y=1.5+RS=1.5+WDA=0.02+HZ=20+DT=0.030+CFG FAIL  (ETA 12485s)
#   [ 159/50000] 155/50000 L=600.0+H=10+V=20+LV=0.75+Y=1.5+RS=1.75+WDA=0.025+HZ=20+DT=0.030+CFG FAIL  (ETA 12450s)
#   [ 160/50000] 156/50000 L=600.0+H=10+V=20+LV=0.75+Y=1.5+RS=1.75+WDA=0.03+HZ=20+DT=0.030+CFG FAIL  (ETA 12443s)
#   [ 161/50000] 164/50000 L=600.0+H=10+V=20+LV=0.75+Y=1.75+RS=1.0+WDA=0.03+HZ=20+DT=0.030+CFG FAIL  (ETA 12410s)
#   [ 162/50000] 163/50000 L=600.0+H=10+V=20+LV=0.75+Y=1.75+RS=1.0+WDA=0.025+HZ=20+DT=0.030+CFG FAIL  (ETA 12345s)
#   [ 163/50000] 162/50000 L=600.0+H=10+V=20+LV=0.75+Y=1.75+RS=1.0+WDA=0.02+HZ=20+DT=0.030+CFG FAIL  (ETA 12282s)
#   [ 164/50000] 165/50000 L=600.0+H=10+V=20+LV=0.75+Y=1.75+RS=1.25+WDA=0.015+HZ=20+DT=0.030+CFG FAIL  (ETA 12225s)
#   [ 165/50000] 173/50000 L=600.0+H=10+V=20+LV=0.75+Y=1.75+RS=1.75+WDA=0.015+HZ=20+DT=0.030+CFG FAIL  (ETA 12193s)
#   [ 166/50000] 161/50000 L=600.0+H=10+V=20+LV=0.75+Y=1.75+RS=1.0+WDA=0.015+HZ=20+DT=0.030+CFG FAIL  (ETA 12162s)
#   [ 167/50000] 174/50000 L=600.0+H=10+V=20+LV=0.75+Y=1.75+RS=1.75+WDA=0.02+HZ=20+DT=0.030+CFG FAIL  (ETA 12089s)
#   [ 168/50000] 167/50000 L=600.0+H=10+V=20+LV=0.75+Y=1.75+RS=1.25+WDA=0.025+HZ=20+DT=0.030+CFG FAIL  (ETA 12067s)
#   [ 169/50000] 166/50000 L=600.0+H=10+V=20+LV=0.75+Y=1.75+RS=1.25+WDA=0.02+HZ=20+DT=0.030+CFG FAIL  (ETA 11997s)
#   [ 170/50000] 175/50000 L=600.0+H=10+V=20+LV=0.75+Y=1.75+RS=1.75+WDA=0.025+HZ=20+DT=0.030+CFG FAIL  (ETA 11935s)
#   [ 171/50000] 172/50000 L=600.0+H=10+V=20+LV=0.75+Y=1.75+RS=1.5+WDA=0.03+HZ=20+DT=0.030+CFG FAIL  (ETA 11893s)
#   [ 172/50000] 169/50000 L=600.0+H=10+V=20+LV=0.75+Y=1.75+RS=1.5+WDA=0.015+HZ=20+DT=0.030+CFG FAIL  (ETA 11827s)
#   [ 173/50000] 176/50000 L=600.0+H=10+V=20+LV=0.75+Y=1.75+RS=1.75+WDA=0.03+HZ=20+DT=0.030+CFG FAIL  (ETA 11762s)
#   [ 174/50000] 168/50000 L=600.0+H=10+V=20+LV=0.75+Y=1.75+RS=1.25+WDA=0.03+HZ=20+DT=0.030+CFG FAIL  (ETA 11695s)
#   [ 175/50000] 177/50000 L=600.0+H=10+V=20+LV=0.75+Y=1.75+RS=2.0+WDA=0.015+HZ=20+DT=0.030+CFG FAIL  (ETA 11651s)
#   [ 176/50000] 178/50000 L=600.0+H=10+V=20+LV=0.75+Y=1.75+RS=2.0+WDA=0.02+HZ=20+DT=0.030+CFG FAIL  (ETA 11594s)
#   [ 177/50000] 179/50000 L=600.0+H=10+V=20+LV=0.75+Y=1.75+RS=2.0+WDA=0.025+HZ=20+DT=0.030+CFG FAIL  (ETA 11555s)
#   [ 178/50000] 180/50000 L=600.0+H=10+V=20+LV=0.75+Y=1.75+RS=2.0+WDA=0.03+HZ=20+DT=0.030+CFG FAIL  (ETA 11520s)
#   [ 179/50000] 171/50000 L=600.0+H=10+V=20+LV=0.75+Y=1.75+RS=1.5+WDA=0.025+HZ=20+DT=0.030+CFG FAIL  (ETA 11614s)
#   [ 180/50000] 170/50000 L=600.0+H=10+V=20+LV=0.75+Y=1.75+RS=1.5+WDA=0.02+HZ=20+DT=0.030+CFG FAIL  (ETA 11571s)
#   [ 181/50000] 184/50000 L=600.0+H=10+V=20+LV=0.75+Y=2.0+RS=1.0+WDA=0.03+HZ=20+DT=0.030+CFG FAIL  (ETA 11557s)
#   [ 182/50000] 189/50000 L=600.0+H=10+V=20+LV=0.75+Y=2.0+RS=1.5+WDA=0.015+HZ=20+DT=0.030+CFG FAIL  (ETA 11503s)
#   [ 183/50000] 187/50000 L=600.0+H=10+V=20+LV=0.75+Y=2.0+RS=1.25+WDA=0.025+HZ=20+DT=0.030+CFG FAIL  (ETA 11470s)
#   [ 184/50000] 182/50000 L=600.0+H=10+V=20+LV=0.75+Y=2.0+RS=1.0+WDA=0.02+HZ=20+DT=0.030+CFG FAIL  (ETA 11453s)
#   [ 185/50000] 181/50000 L=600.0+H=10+V=20+LV=0.75+Y=2.0+RS=1.0+WDA=0.015+HZ=20+DT=0.030+CFG FAIL  (ETA 11398s)
#   [ 186/50000] 193/50000 L=600.0+H=10+V=20+LV=0.75+Y=2.0+RS=1.75+WDA=0.015+HZ=20+DT=0.030+CFG FAIL  (ETA 11392s)
#   [ 187/50000] 183/50000 L=600.0+H=10+V=20+LV=0.75+Y=2.0+RS=1.0+WDA=0.025+HZ=20+DT=0.030+CFG FAIL  (ETA 11357s)
#   [ 188/50000] 185/50000 L=600.0+H=10+V=20+LV=0.75+Y=2.0+RS=1.25+WDA=0.015+HZ=20+DT=0.030+CFG FAIL  (ETA 11305s)
#   [ 189/50000] 190/50000 L=600.0+H=10+V=20+LV=0.75+Y=2.0+RS=1.5+WDA=0.02+HZ=20+DT=0.030+CFG FAIL  (ETA 11248s)
#   [ 190/50000] 188/50000 L=600.0+H=10+V=20+LV=0.75+Y=2.0+RS=1.25+WDA=0.03+HZ=20+DT=0.030+CFG FAIL  (ETA 11215s)
#   [ 191/50000] 194/50000 L=600.0+H=10+V=20+LV=0.75+Y=2.0+RS=1.75+WDA=0.02+HZ=20+DT=0.030+CFG FAIL  (ETA 11197s)
#   [ 192/50000] 191/50000 L=600.0+H=10+V=20+LV=0.75+Y=2.0+RS=1.5+WDA=0.025+HZ=20+DT=0.030+CFG FAIL  (ETA 11200s)
#   [ 193/50000] 192/50000 L=600.0+H=10+V=20+LV=0.75+Y=2.0+RS=1.5+WDA=0.03+HZ=20+DT=0.030+CFG FAIL  (ETA 11183s)
#   [ 194/50000] 200/50000 L=600.0+H=10+V=20+LV=0.75+Y=2.0+RS=2.0+WDA=0.03+HZ=20+DT=0.030+CFG FAIL  (ETA 11225s)
#   [ 195/50000] 197/50000 L=600.0+H=10+V=20+LV=0.75+Y=2.0+RS=2.0+WDA=0.015+HZ=20+DT=0.030+CFG FAIL  (ETA 11255s)
#   [ 196/50000] 201/50000 L=600.0+H=10+V=20+LV=1.0+Y=1.0+RS=1.0+WDA=0.015+HZ=20+DT=0.030+CFG FAIL  (ETA 11199s)
#   [ 197/50000] 195/50000 L=600.0+H=10+V=20+LV=0.75+Y=2.0+RS=1.75+WDA=0.025+HZ=20+DT=0.030+CFG FAIL  (ETA 11143s)
#   [ 198/50000] 203/50000 L=600.0+H=10+V=20+LV=1.0+Y=1.0+RS=1.0+WDA=0.025+HZ=20+DT=0.030+CFG FAIL  (ETA 11118s)
#   [ 199/50000] 186/50000 L=600.0+H=10+V=20+LV=0.75+Y=2.0+RS=1.25+WDA=0.02+HZ=20+DT=0.030+CFG FAIL  (ETA 11071s)
#   [ 200/50000] 199/50000 L=600.0+H=10+V=20+LV=0.75+Y=2.0+RS=2.0+WDA=0.025+HZ=20+DT=0.030+CFG FAIL  (ETA 11019s)
#   [ 201/50000] 198/50000 L=600.0+H=10+V=20+LV=0.75+Y=2.0+RS=2.0+WDA=0.02+HZ=20+DT=0.030+CFG FAIL  (ETA 11062s)
#   [ 202/50000] 202/50000 L=600.0+H=10+V=20+LV=1.0+Y=1.0+RS=1.0+WDA=0.02+HZ=20+DT=0.030+CFG FAIL  (ETA 11046s)
#   [ 203/50000] 196/50000 L=600.0+H=10+V=20+LV=0.75+Y=2.0+RS=1.75+WDA=0.03+HZ=20+DT=0.030+CFG FAIL  (ETA 11030s)
#   [ 204/50000] 206/50000 L=600.0+H=10+V=20+LV=1.0+Y=1.0+RS=1.25+WDA=0.02+HZ=20+DT=0.030+CFG FAIL  (ETA 11034s)
#   [ 205/50000] 204/50000 L=600.0+H=10+V=20+LV=1.0+Y=1.0+RS=1.0+WDA=0.03+HZ=20+DT=0.030+CFG FAIL  (ETA 11190s)
#   [ 206/50000] 210/50000 L=600.0+H=10+V=20+LV=1.0+Y=1.0+RS=1.5+WDA=0.02+HZ=20+DT=0.030+CFG FAIL  (ETA 11203s)
#   [ 207/50000] 207/50000 L=600.0+H=10+V=20+LV=1.0+Y=1.0+RS=1.25+WDA=0.025+HZ=20+DT=0.030+CFG FAIL  (ETA 11170s)
#   [ 208/50000] 211/50000 L=600.0+H=10+V=20+LV=1.0+Y=1.0+RS=1.5+WDA=0.025+HZ=20+DT=0.030+CFG FAIL  (ETA 11159s)
#   [ 209/50000] 205/50000 L=600.0+H=10+V=20+LV=1.0+Y=1.0+RS=1.25+WDA=0.015+HZ=20+DT=0.030+CFG FAIL  (ETA 11134s)
#   [ 210/50000] 218/50000 L=600.0+H=10+V=20+LV=1.0+Y=1.0+RS=2.0+WDA=0.02+HZ=20+DT=0.030+CFG FAIL  (ETA 11099s)
#   [ 211/50000] 208/50000 L=600.0+H=10+V=20+LV=1.0+Y=1.0+RS=1.25+WDA=0.03+HZ=20+DT=0.030+CFG FAIL  (ETA 11089s)
#   [ 212/50000] 214/50000 L=600.0+H=10+V=20+LV=1.0+Y=1.0+RS=1.75+WDA=0.02+HZ=20+DT=0.030+CFG FAIL  (ETA 11050s)
#   [ 213/50000] 217/50000 L=600.0+H=10+V=20+LV=1.0+Y=1.0+RS=2.0+WDA=0.015+HZ=20+DT=0.030+CFG FAIL  (ETA 11018s)
#   [ 214/50000] 213/50000 L=600.0+H=10+V=20+LV=1.0+Y=1.0+RS=1.75+WDA=0.015+HZ=20+DT=0.030+CFG FAIL  (ETA 11024s)
#   [ 215/50000] 219/50000 L=600.0+H=10+V=20+LV=1.0+Y=1.0+RS=2.0+WDA=0.025+HZ=20+DT=0.030+CFG FAIL  (ETA 10982s)
#   [ 216/50000] 220/50000 L=600.0+H=10+V=20+LV=1.0+Y=1.0+RS=2.0+WDA=0.03+HZ=20+DT=0.030+CFG FAIL  (ETA 10951s)
#   [ 217/50000] 215/50000 L=600.0+H=10+V=20+LV=1.0+Y=1.0+RS=1.75+WDA=0.025+HZ=20+DT=0.030+CFG FAIL  (ETA 10986s)
#   [ 218/50000] 212/50000 L=600.0+H=10+V=20+LV=1.0+Y=1.0+RS=1.5+WDA=0.03+HZ=20+DT=0.030+CFG FAIL  (ETA 10941s)
#   [ 219/50000] 222/50000 L=600.0+H=10+V=20+LV=1.0+Y=1.25+RS=1.0+WDA=0.02+HZ=20+DT=0.030+CFG FAIL  (ETA 10988s)
#   [ 220/50000] 221/50000 L=600.0+H=10+V=20+LV=1.0+Y=1.25+RS=1.0+WDA=0.015+HZ=20+DT=0.030+CFG FAIL  (ETA 10942s)
#   [ 221/50000] 223/50000 L=600.0+H=10+V=20+LV=1.0+Y=1.25+RS=1.0+WDA=0.025+HZ=20+DT=0.030+CFG FAIL  (ETA 10903s)
#   [ 222/50000] 224/50000 L=600.0+H=10+V=20+LV=1.0+Y=1.25+RS=1.0+WDA=0.03+HZ=20+DT=0.030+CFG FAIL  (ETA 10863s)
#   [ 223/50000] 225/50000 L=600.0+H=10+V=20+LV=1.0+Y=1.25+RS=1.25+WDA=0.015+HZ=20+DT=0.030+CFG FAIL  (ETA 10898s)
#   [ 224/50000] 228/50000 L=600.0+H=10+V=20+LV=1.0+Y=1.25+RS=1.25+WDA=0.03+HZ=20+DT=0.030+CFG FAIL  (ETA 10865s)
#   [ 225/50000] 229/50000 L=600.0+H=10+V=20+LV=1.0+Y=1.25+RS=1.5+WDA=0.015+HZ=20+DT=0.030+CFG FAIL  (ETA 10835s)
#   [ 226/50000] 209/50000 L=600.0+H=10+V=20+LV=1.0+Y=1.0+RS=1.5+WDA=0.015+HZ=20+DT=0.030+CFG FAIL  (ETA 10807s)
#   [ 227/50000] 216/50000 L=600.0+H=10+V=20+LV=1.0+Y=1.0+RS=1.75+WDA=0.03+HZ=20+DT=0.030+CFG FAIL  (ETA 10799s)
#   [ 228/50000] 227/50000 L=600.0+H=10+V=20+LV=1.0+Y=1.25+RS=1.25+WDA=0.025+HZ=20+DT=0.030+CFG FAIL  (ETA 10816s)
#   [ 229/50000] 233/50000 L=600.0+H=10+V=20+LV=1.0+Y=1.25+RS=1.75+WDA=0.015+HZ=20+DT=0.030+CFG FAIL  (ETA 10809s)
#   [ 230/50000] 232/50000 L=600.0+H=10+V=20+LV=1.0+Y=1.25+RS=1.5+WDA=0.03+HZ=20+DT=0.030+CFG FAIL  (ETA 10833s)
#   [ 231/50000] 234/50000 L=600.0+H=10+V=20+LV=1.0+Y=1.25+RS=1.75+WDA=0.02+HZ=20+DT=0.030+CFG FAIL  (ETA 10787s)
#   [ 232/50000] 231/50000 L=600.0+H=10+V=20+LV=1.0+Y=1.25+RS=1.5+WDA=0.025+HZ=20+DT=0.030+CFG FAIL  (ETA 10746s)
#   [ 233/50000] 236/50000 L=600.0+H=10+V=20+LV=1.0+Y=1.25+RS=1.75+WDA=0.03+HZ=20+DT=0.030+CFG FAIL  (ETA 10711s)
#   [ 234/50000] 235/50000 L=600.0+H=10+V=20+LV=1.0+Y=1.25+RS=1.75+WDA=0.025+HZ=20+DT=0.030+CFG FAIL  (ETA 10672s)
#   [ 235/50000] 226/50000 L=600.0+H=10+V=20+LV=1.0+Y=1.25+RS=1.25+WDA=0.02+HZ=20+DT=0.030+CFG FAIL  (ETA 10681s)
#   [ 236/50000] 230/50000 L=600.0+H=10+V=20+LV=1.0+Y=1.25+RS=1.5+WDA=0.02+HZ=20+DT=0.030+CFG FAIL  (ETA 10732s)
#   [ 237/50000] 242/50000 L=600.0+H=10+V=20+LV=1.0+Y=1.5+RS=1.0+WDA=0.02+HZ=20+DT=0.030+CFG FAIL  (ETA 10742s)
#   [ 238/50000] 238/50000 L=600.0+H=10+V=20+LV=1.0+Y=1.25+RS=2.0+WDA=0.02+HZ=20+DT=0.030+CFG FAIL  (ETA 10710s)
#   [ 239/50000] 237/50000 L=600.0+H=10+V=20+LV=1.0+Y=1.25+RS=2.0+WDA=0.015+HZ=20+DT=0.030+CFG FAIL  (ETA 10706s)
#   [ 240/50000] 246/50000 L=600.0+H=10+V=20+LV=1.0+Y=1.5+RS=1.25+WDA=0.02+HZ=20+DT=0.030+CFG FAIL  (ETA 10664s)
#   [ 241/50000] 241/50000 L=600.0+H=10+V=20+LV=1.0+Y=1.5+RS=1.0+WDA=0.015+HZ=20+DT=0.030+CFG FAIL  (ETA 10712s)
#   [ 242/50000] 247/50000 L=600.0+H=10+V=20+LV=1.0+Y=1.5+RS=1.25+WDA=0.025+HZ=20+DT=0.030+CFG FAIL  (ETA 10670s)
#   [ 243/50000] 239/50000 L=600.0+H=10+V=20+LV=1.0+Y=1.25+RS=2.0+WDA=0.025+HZ=20+DT=0.030+CFG FAIL  (ETA 10639s)
#   [ 244/50000] 249/50000 L=600.0+H=10+V=20+LV=1.0+Y=1.5+RS=1.5+WDA=0.015+HZ=20+DT=0.030+CFG FAIL  (ETA 10601s)
#   [ 245/50000] 248/50000 L=600.0+H=10+V=20+LV=1.0+Y=1.5+RS=1.25+WDA=0.03+HZ=20+DT=0.030+CFG FAIL  (ETA 10561s)
#   [ 246/50000] 250/50000 L=600.0+H=10+V=20+LV=1.0+Y=1.5+RS=1.5+WDA=0.02+HZ=20+DT=0.030+CFG FAIL  (ETA 10576s)
#   [ 247/50000] 245/50000 L=600.0+H=10+V=20+LV=1.0+Y=1.5+RS=1.25+WDA=0.015+HZ=20+DT=0.030+CFG FAIL  (ETA 10566s)
#   [ 248/50000] 244/50000 L=600.0+H=10+V=20+LV=1.0+Y=1.5+RS=1.0+WDA=0.03+HZ=20+DT=0.030+CFG FAIL  (ETA 10556s)
#   [ 249/50000] 243/50000 L=600.0+H=10+V=20+LV=1.0+Y=1.5+RS=1.0+WDA=0.025+HZ=20+DT=0.030+CFG FAIL  (ETA 10569s)
#   [ 250/50000] 251/50000 L=600.0+H=10+V=20+LV=1.0+Y=1.5+RS=1.5+WDA=0.025+HZ=20+DT=0.030+CFG FAIL  (ETA 10595s)
#   [ 251/50000] 252/50000 L=600.0+H=10+V=20+LV=1.0+Y=1.5+RS=1.5+WDA=0.03+HZ=20+DT=0.030+CFG FAIL  (ETA 10625s)
#   [ 252/50000] 240/50000 L=600.0+H=10+V=20+LV=1.0+Y=1.25+RS=2.0+WDA=0.03+HZ=20+DT=0.030+CFG FAIL  (ETA 10585s)
#   [ 253/50000] 257/50000 L=600.0+H=10+V=20+LV=1.0+Y=1.5+RS=2.0+WDA=0.015+HZ=20+DT=0.030+CFG FAIL  (ETA 10579s)
#   [ 254/50000] 255/50000 L=600.0+H=10+V=20+LV=1.0+Y=1.5+RS=1.75+WDA=0.025+HZ=20+DT=0.030+CFG FAIL  (ETA 10540s)
#   [ 255/50000] 261/50000 L=600.0+H=10+V=20+LV=1.0+Y=1.75+RS=1.0+WDA=0.015+HZ=20+DT=0.030+CFG FAIL  (ETA 10538s)
#   [ 256/50000] 260/50000 L=600.0+H=10+V=20+LV=1.0+Y=1.5+RS=2.0+WDA=0.03+HZ=20+DT=0.030+CFG FAIL  (ETA 10562s)
#   [ 257/50000] 253/50000 L=600.0+H=10+V=20+LV=1.0+Y=1.5+RS=1.75+WDA=0.015+HZ=20+DT=0.030+CFG FAIL  (ETA 10535s)
#   [ 258/50000] 262/50000 L=600.0+H=10+V=20+LV=1.0+Y=1.75+RS=1.0+WDA=0.02+HZ=20+DT=0.030+CFG FAIL  (ETA 10499s)
#   [ 259/50000] 259/50000 L=600.0+H=10+V=20+LV=1.0+Y=1.5+RS=2.0+WDA=0.025+HZ=20+DT=0.030+CFG FAIL  (ETA 10463s)
#   [ 260/50000] 256/50000 L=600.0+H=10+V=20+LV=1.0+Y=1.5+RS=1.75+WDA=0.03+HZ=20+DT=0.030+CFG FAIL  (ETA 10423s)
#   [ 261/50000] 254/50000 L=600.0+H=10+V=20+LV=1.0+Y=1.5+RS=1.75+WDA=0.02+HZ=20+DT=0.030+CFG FAIL  (ETA 10398s)
#   [ 262/50000] 263/50000 L=600.0+H=10+V=20+LV=1.0+Y=1.75+RS=1.0+WDA=0.025+HZ=20+DT=0.030+CFG FAIL  (ETA 10426s)
#   [ 263/50000] 270/50000 L=600.0+H=10+V=20+LV=1.0+Y=1.75+RS=1.5+WDA=0.02+HZ=20+DT=0.030+CFG FAIL  (ETA 10408s)
#   [ 264/50000] 264/50000 L=600.0+H=10+V=20+LV=1.0+Y=1.75+RS=1.0+WDA=0.03+HZ=20+DT=0.030+CFG FAIL  (ETA 10461s)
#   [ 265/50000] 268/50000 L=600.0+H=10+V=20+LV=1.0+Y=1.75+RS=1.25+WDA=0.03+HZ=20+DT=0.030+CFG FAIL  (ETA 10444s)
#   [ 266/50000] 269/50000 L=600.0+H=10+V=20+LV=1.0+Y=1.75+RS=1.5+WDA=0.015+HZ=20+DT=0.030+CFG FAIL  (ETA 10411s)
#   [ 267/50000] 272/50000 L=600.0+H=10+V=20+LV=1.0+Y=1.75+RS=1.5+WDA=0.03+HZ=20+DT=0.030+CFG FAIL  (ETA 10390s)
#   [ 268/50000] 258/50000 L=600.0+H=10+V=20+LV=1.0+Y=1.5+RS=2.0+WDA=0.02+HZ=20+DT=0.030+CFG FAIL  (ETA 10351s)
#   [ 269/50000] 276/50000 L=600.0+H=10+V=20+LV=1.0+Y=1.75+RS=1.75+WDA=0.03+HZ=20+DT=0.030+CFG FAIL  (ETA 10354s)
#   [ 270/50000] 265/50000 L=600.0+H=10+V=20+LV=1.0+Y=1.75+RS=1.25+WDA=0.015+HZ=20+DT=0.030+CFG FAIL  (ETA 10344s)
#   [ 271/50000] 271/50000 L=600.0+H=10+V=20+LV=1.0+Y=1.75+RS=1.5+WDA=0.025+HZ=20+DT=0.030+CFG FAIL  (ETA 10310s)
#   [ 272/50000] 267/50000 L=600.0+H=10+V=20+LV=1.0+Y=1.75+RS=1.25+WDA=0.025+HZ=20+DT=0.030+CFG FAIL  (ETA 10322s)
#   [ 273/50000] 275/50000 L=600.0+H=10+V=20+LV=1.0+Y=1.75+RS=1.75+WDA=0.025+HZ=20+DT=0.030+CFG FAIL  (ETA 10309s)
#   [ 274/50000] 266/50000 L=600.0+H=10+V=20+LV=1.0+Y=1.75+RS=1.25+WDA=0.02+HZ=20+DT=0.030+CFG FAIL  (ETA 10274s)
#   [ 275/50000] 286/50000 L=600.0+H=10+V=20+LV=1.0+Y=2.0+RS=1.25+WDA=0.02+HZ=20+DT=0.030+CFG FAIL  (ETA 10300s)
#   [ 276/50000] 274/50000 L=600.0+H=10+V=20+LV=1.0+Y=1.75+RS=1.75+WDA=0.02+HZ=20+DT=0.030+CFG FAIL  (ETA 10270s)
#   [ 277/50000] 281/50000 L=600.0+H=10+V=20+LV=1.0+Y=2.0+RS=1.0+WDA=0.015+HZ=20+DT=0.030+CFG FAIL  (ETA 10240s)
#   [ 278/50000] 285/50000 L=600.0+H=10+V=20+LV=1.0+Y=2.0+RS=1.25+WDA=0.015+HZ=20+DT=0.030+CFG FAIL  (ETA 10207s)
#   [ 279/50000] 282/50000 L=600.0+H=10+V=20+LV=1.0+Y=2.0+RS=1.0+WDA=0.02+HZ=20+DT=0.030+CFG FAIL  (ETA 10176s)
#   [ 280/50000] 278/50000 L=600.0+H=10+V=20+LV=1.0+Y=1.75+RS=2.0+WDA=0.02+HZ=20+DT=0.030+CFG FAIL  (ETA 10142s)
#   [ 281/50000] 283/50000 L=600.0+H=10+V=20+LV=1.0+Y=2.0+RS=1.0+WDA=0.025+HZ=20+DT=0.030+CFG FAIL  (ETA 10168s)
#   [ 282/50000] 277/50000 L=600.0+H=10+V=20+LV=1.0+Y=1.75+RS=2.0+WDA=0.015+HZ=20+DT=0.030+CFG FAIL  (ETA 10148s)
#   [ 283/50000] 273/50000 L=600.0+H=10+V=20+LV=1.0+Y=1.75+RS=1.75+WDA=0.015+HZ=20+DT=0.030+CFG FAIL  (ETA 10160s)
#   [ 284/50000] 287/50000 L=600.0+H=10+V=20+LV=1.0+Y=2.0+RS=1.25+WDA=0.025+HZ=20+DT=0.030+CFG FAIL  (ETA 10143s)
#   [ 285/50000] 289/50000 L=600.0+H=10+V=20+LV=1.0+Y=2.0+RS=1.5+WDA=0.015+HZ=20+DT=0.030+CFG FAIL  (ETA 10120s)
#   [ 286/50000] 284/50000 L=600.0+H=10+V=20+LV=1.0+Y=2.0+RS=1.0+WDA=0.03+HZ=20+DT=0.030+CFG FAIL  (ETA 10103s)
#   [ 287/50000] 279/50000 L=600.0+H=10+V=20+LV=1.0+Y=1.75+RS=2.0+WDA=0.025+HZ=20+DT=0.030+CFG FAIL  (ETA 10098s)
#   [ 288/50000] 288/50000 L=600.0+H=10+V=20+LV=1.0+Y=2.0+RS=1.25+WDA=0.03+HZ=20+DT=0.030+CFG FAIL  (ETA 10067s)
#   [ 289/50000] 294/50000 L=600.0+H=10+V=20+LV=1.0+Y=2.0+RS=1.75+WDA=0.02+HZ=20+DT=0.030+CFG FAIL  (ETA 10050s)
#   [ 290/50000] 293/50000 L=600.0+H=10+V=20+LV=1.0+Y=2.0+RS=1.75+WDA=0.015+HZ=20+DT=0.030+CFG FAIL  (ETA 10050s)
#   [ 291/50000] 296/50000 L=600.0+H=10+V=20+LV=1.0+Y=2.0+RS=1.75+WDA=0.03+HZ=20+DT=0.030+CFG FAIL  (ETA 10070s)
#   [ 292/50000] 290/50000 L=600.0+H=10+V=20+LV=1.0+Y=2.0+RS=1.5+WDA=0.02+HZ=20+DT=0.030+CFG FAIL  (ETA 10051s)
#   [ 293/50000] 291/50000 L=600.0+H=10+V=20+LV=1.0+Y=2.0+RS=1.5+WDA=0.025+HZ=20+DT=0.030+CFG FAIL  (ETA 10025s)
#   [ 294/50000] 299/50000 L=600.0+H=10+V=20+LV=1.0+Y=2.0+RS=2.0+WDA=0.025+HZ=20+DT=0.030+CFG FAIL  (ETA 10031s)
#   [ 295/50000] 295/50000 L=600.0+H=10+V=20+LV=1.0+Y=2.0+RS=1.75+WDA=0.025+HZ=20+DT=0.030+CFG FAIL  (ETA 10017s)
#   [ 296/50000] 292/50000 L=600.0+H=10+V=20+LV=1.0+Y=2.0+RS=1.5+WDA=0.03+HZ=20+DT=0.030+CFG FAIL  (ETA 10013s)
#   [ 297/50000] 280/50000 L=600.0+H=10+V=20+LV=1.0+Y=1.75+RS=2.0+WDA=0.03+HZ=20+DT=0.030+CFG FAIL  (ETA 9994s)
#   [ 298/50000] 302/50000 L=600.0+H=10+V=20+LV=1.25+Y=1.0+RS=1.0+WDA=0.02+HZ=20+DT=0.030+CFG FAIL  (ETA 10101s)
#   [ 299/50000] 298/50000 L=600.0+H=10+V=20+LV=1.0+Y=2.0+RS=2.0+WDA=0.02+HZ=20+DT=0.030+CFG FAIL  (ETA 10078s)
#   [ 300/50000] 297/50000 L=600.0+H=10+V=20+LV=1.0+Y=2.0+RS=2.0+WDA=0.015+HZ=20+DT=0.030+CFG FAIL  (ETA 10076s)
#   [ 301/50000] 301/50000 L=600.0+H=10+V=20+LV=1.25+Y=1.0+RS=1.0+WDA=0.015+HZ=20+DT=0.030+CFG FAIL  (ETA 10075s)
#   [ 302/50000] 306/50000 L=600.0+H=10+V=20+LV=1.25+Y=1.0+RS=1.25+WDA=0.02+HZ=20+DT=0.030+CFG FAIL  (ETA 10055s)
#   [ 303/50000] 304/50000 L=600.0+H=10+V=20+LV=1.25+Y=1.0+RS=1.0+WDA=0.03+HZ=20+DT=0.030+CFG FAIL  (ETA 10022s)
#   [ 304/50000] 305/50000 L=600.0+H=10+V=20+LV=1.25+Y=1.0+RS=1.25+WDA=0.015+HZ=20+DT=0.030+CFG FAIL  (ETA 9990s)
#   [ 305/50000] 308/50000 L=600.0+H=10+V=20+LV=1.25+Y=1.0+RS=1.25+WDA=0.03+HZ=20+DT=0.030+CFG FAIL  (ETA 9995s)
#   [ 306/50000] 300/50000 L=600.0+H=10+V=20+LV=1.0+Y=2.0+RS=2.0+WDA=0.03+HZ=20+DT=0.030+CFG FAIL  (ETA 9987s)
#   [ 307/50000] 310/50000 L=600.0+H=10+V=20+LV=1.25+Y=1.0+RS=1.5+WDA=0.02+HZ=20+DT=0.030+CFG FAIL  (ETA 9965s)
#   [ 308/50000] 312/50000 L=600.0+H=10+V=20+LV=1.25+Y=1.0+RS=1.5+WDA=0.03+HZ=20+DT=0.030+CFG FAIL  (ETA 9977s)
#   [ 309/50000] 313/50000 L=600.0+H=10+V=20+LV=1.25+Y=1.0+RS=1.75+WDA=0.015+HZ=20+DT=0.030+CFG FAIL  (ETA 10014s)
#   [ 310/50000] 307/50000 L=600.0+H=10+V=20+LV=1.25+Y=1.0+RS=1.25+WDA=0.025+HZ=20+DT=0.030+CFG FAIL  (ETA 9983s)
#   [ 311/50000] 315/50000 L=600.0+H=10+V=20+LV=1.25+Y=1.0+RS=1.75+WDA=0.025+HZ=20+DT=0.030+CFG FAIL  (ETA 9973s)
#   [ 312/50000] 311/50000 L=600.0+H=10+V=20+LV=1.25+Y=1.0+RS=1.5+WDA=0.025+HZ=20+DT=0.030+CFG FAIL  (ETA 9952s)
#   [ 313/50000] 303/50000 L=600.0+H=10+V=20+LV=1.25+Y=1.0+RS=1.0+WDA=0.025+HZ=20+DT=0.030+CFG FAIL  (ETA 10018s)
#   [ 314/50000] 309/50000 L=600.0+H=10+V=20+LV=1.25+Y=1.0+RS=1.5+WDA=0.015+HZ=20+DT=0.030+CFG FAIL  (ETA 10034s)
#   [ 315/50000] 318/50000 L=600.0+H=10+V=20+LV=1.25+Y=1.0+RS=2.0+WDA=0.02+HZ=20+DT=0.030+CFG FAIL  (ETA 10004s)
#   [ 316/50000] 314/50000 L=600.0+H=10+V=20+LV=1.25+Y=1.0+RS=1.75+WDA=0.02+HZ=20+DT=0.030+CFG FAIL  (ETA 9987s)
#   [ 317/50000] 322/50000 L=600.0+H=10+V=20+LV=1.25+Y=1.25+RS=1.0+WDA=0.02+HZ=20+DT=0.030+CFG FAIL  (ETA 10008s)
#   [ 318/50000] 317/50000 L=600.0+H=10+V=20+LV=1.25+Y=1.0+RS=2.0+WDA=0.015+HZ=20+DT=0.030+CFG FAIL  (ETA 9987s)
#   [ 319/50000] 323/50000 L=600.0+H=10+V=20+LV=1.25+Y=1.25+RS=1.0+WDA=0.025+HZ=20+DT=0.030+CFG FAIL  (ETA 10051s)
#   [ 320/50000] 324/50000 L=600.0+H=10+V=20+LV=1.25+Y=1.25+RS=1.0+WDA=0.03+HZ=20+DT=0.030+CFG FAIL  (ETA 10080s)
#   [ 321/50000] 321/50000 L=600.0+H=10+V=20+LV=1.25+Y=1.25+RS=1.0+WDA=0.015+HZ=20+DT=0.030+CFG FAIL  (ETA 10090s)
#   [ 322/50000] 316/50000 L=600.0+H=10+V=20+LV=1.25+Y=1.0+RS=1.75+WDA=0.03+HZ=20+DT=0.030+CFG FAIL  (ETA 10069s)
#   [ 323/50000] 326/50000 L=600.0+H=10+V=20+LV=1.25+Y=1.25+RS=1.25+WDA=0.02+HZ=20+DT=0.030+CFG FAIL  (ETA 10157s)
#   [ 324/50000] 327/50000 L=600.0+H=10+V=20+LV=1.25+Y=1.25+RS=1.25+WDA=0.025+HZ=20+DT=0.030+CFG FAIL  (ETA 10132s)
#   [ 325/50000] 319/50000 L=600.0+H=10+V=20+LV=1.25+Y=1.0+RS=2.0+WDA=0.025+HZ=20+DT=0.030+CFG FAIL  (ETA 10187s)
#   [ 326/50000] 332/50000 L=600.0+H=10+V=20+LV=1.25+Y=1.25+RS=1.5+WDA=0.03+HZ=20+DT=0.030+CFG FAIL  (ETA 10184s)
#   [ 327/50000] 331/50000 L=600.0+H=10+V=20+LV=1.25+Y=1.25+RS=1.5+WDA=0.025+HZ=20+DT=0.030+CFG FAIL  (ETA 10213s)
#   [ 328/50000] 333/50000 L=600.0+H=10+V=20+LV=1.25+Y=1.25+RS=1.75+WDA=0.015+HZ=20+DT=0.030+CFG FAIL  (ETA 10212s)
#   [ 329/50000] 336/50000 L=600.0+H=10+V=20+LV=1.25+Y=1.25+RS=1.75+WDA=0.03+HZ=20+DT=0.030+CFG FAIL  (ETA 10201s)
#   [ 330/50000] 337/50000 L=600.0+H=10+V=20+LV=1.25+Y=1.25+RS=2.0+WDA=0.015+HZ=20+DT=0.030+CFG FAIL  (ETA 10200s)
#   [ 331/50000] 325/50000 L=600.0+H=10+V=20+LV=1.25+Y=1.25+RS=1.25+WDA=0.015+HZ=20+DT=0.030+CFG FAIL  (ETA 10172s)
#   [ 332/50000] 328/50000 L=600.0+H=10+V=20+LV=1.25+Y=1.25+RS=1.25+WDA=0.03+HZ=20+DT=0.030+CFG FAIL  (ETA 10144s)
#   [ 333/50000] 334/50000 L=600.0+H=10+V=20+LV=1.25+Y=1.25+RS=1.75+WDA=0.02+HZ=20+DT=0.030+CFG FAIL  (ETA 10119s)
#   [ 334/50000] 329/50000 L=600.0+H=10+V=20+LV=1.25+Y=1.25+RS=1.5+WDA=0.015+HZ=20+DT=0.030+CFG FAIL  (ETA 10147s)
#   [ 335/50000] 335/50000 L=600.0+H=10+V=20+LV=1.25+Y=1.25+RS=1.75+WDA=0.025+HZ=20+DT=0.030+CFG FAIL  (ETA 10190s)
#   [ 336/50000] 340/50000 L=600.0+H=10+V=20+LV=1.25+Y=1.25+RS=2.0+WDA=0.03+HZ=20+DT=0.030+CFG FAIL  (ETA 10189s)
#   [ 337/50000] 330/50000 L=600.0+H=10+V=20+LV=1.25+Y=1.25+RS=1.5+WDA=0.02+HZ=20+DT=0.030+CFG FAIL  (ETA 10185s)
#   [ 338/50000] 341/50000 L=600.0+H=10+V=20+LV=1.25+Y=1.5+RS=1.0+WDA=0.015+HZ=20+DT=0.030+CFG FAIL  (ETA 10155s)
#   [ 339/50000] 339/50000 L=600.0+H=10+V=20+LV=1.25+Y=1.25+RS=2.0+WDA=0.025+HZ=20+DT=0.030+CFG FAIL  (ETA 10133s)
#   [ 340/50000] 338/50000 L=600.0+H=10+V=20+LV=1.25+Y=1.25+RS=2.0+WDA=0.02+HZ=20+DT=0.030+CFG FAIL  (ETA 10124s)
#   [ 341/50000] 344/50000 L=600.0+H=10+V=20+LV=1.25+Y=1.5+RS=1.0+WDA=0.03+HZ=20+DT=0.030+CFG FAIL  (ETA 10104s)
#   [ 342/50000] 320/50000 L=600.0+H=10+V=20+LV=1.25+Y=1.0+RS=2.0+WDA=0.03+HZ=20+DT=0.030+CFG FAIL  (ETA 10091s)
#   [ 343/50000] 343/50000 L=600.0+H=10+V=20+LV=1.25+Y=1.5+RS=1.0+WDA=0.025+HZ=20+DT=0.030+CFG FAIL  (ETA 10120s)
#   [ 344/50000] 346/50000 L=600.0+H=10+V=20+LV=1.25+Y=1.5+RS=1.25+WDA=0.02+HZ=20+DT=0.030+CFG FAIL  (ETA 10127s)
#   [ 345/50000] 342/50000 L=600.0+H=10+V=20+LV=1.25+Y=1.5+RS=1.0+WDA=0.02+HZ=20+DT=0.030+CFG FAIL  (ETA 10113s)
#   [ 346/50000] 350/50000 L=600.0+H=10+V=20+LV=1.25+Y=1.5+RS=1.5+WDA=0.02+HZ=20+DT=0.030+CFG FAIL  (ETA 10098s)
#   [ 347/50000] 352/50000 L=600.0+H=10+V=20+LV=1.25+Y=1.5+RS=1.5+WDA=0.03+HZ=20+DT=0.030+CFG FAIL  (ETA 10132s)
#   [ 348/50000] 351/50000 L=600.0+H=10+V=20+LV=1.25+Y=1.5+RS=1.5+WDA=0.025+HZ=20+DT=0.030+CFG FAIL  (ETA 10161s)
#   [ 349/50000] 349/50000 L=600.0+H=10+V=20+LV=1.25+Y=1.5+RS=1.5+WDA=0.015+HZ=20+DT=0.030+CFG FAIL  (ETA 10140s)
#   [ 350/50000] 345/50000 L=600.0+H=10+V=20+LV=1.25+Y=1.5+RS=1.25+WDA=0.015+HZ=20+DT=0.030+CFG FAIL  (ETA 10133s)
#   [ 351/50000] 355/50000 L=600.0+H=10+V=20+LV=1.25+Y=1.5+RS=1.75+WDA=0.025+HZ=20+DT=0.030+CFG FAIL  (ETA 10134s)
#   [ 352/50000] 347/50000 L=600.0+H=10+V=20+LV=1.25+Y=1.5+RS=1.25+WDA=0.025+HZ=20+DT=0.030+CFG FAIL  (ETA 10123s)
#   [ 353/50000] 362/50000 L=600.0+H=10+V=20+LV=1.25+Y=1.75+RS=1.0+WDA=0.02+HZ=20+DT=0.030+CFG FAIL  (ETA 10220s)
#   [ 354/50000] 348/50000 L=600.0+H=10+V=20+LV=1.25+Y=1.5+RS=1.25+WDA=0.03+HZ=20+DT=0.030+CFG FAIL  (ETA 10194s)
#   [ 355/50000] 361/50000 L=600.0+H=10+V=20+LV=1.25+Y=1.75+RS=1.0+WDA=0.015+HZ=20+DT=0.030+CFG FAIL  (ETA 10171s)
#   [ 356/50000] 356/50000 L=600.0+H=10+V=20+LV=1.25+Y=1.5+RS=1.75+WDA=0.03+HZ=20+DT=0.030+CFG FAIL  (ETA 10153s)
#   [ 357/50000] 363/50000 L=600.0+H=10+V=20+LV=1.25+Y=1.75+RS=1.0+WDA=0.025+HZ=20+DT=0.030+CFG FAIL  (ETA 10141s)
# ...
#   [2507/50000] 2505/50000 L=600.0+H=15+V=20+LV=0.5+Y=1.0+RS=1.25+WDA=0.015+HZ=20+DT=0.030+CFG FAIL  (ETA 13204s)
#   [2508/50000] 2516/50000 L=600.0+H=15+V=20+LV=0.5+Y=1.0+RS=1.75+WDA=0.03+HZ=20+DT=0.030+CFG FAIL  (ETA 13203s)
#   [2509/50000] 2511/50000 L=600.0+H=15+V=20+LV=0.5+Y=1.0+RS=1.5+WDA=0.025+HZ=20+DT=0.030+CFG FAIL  (ETA 13200s)
#   [2510/50000] 2512/50000 L=600.0+H=15+V=20+LV=0.5+Y=1.0+RS=1.5+WDA=0.03+HZ=20+DT=0.030+CFG FAIL  (ETA 13198s)
#   [2511/50000] 2499/50000 L=600.0+H=10+V=40+LV=1.5+Y=2.0+RS=2.0+WDA=0.025+HZ=20+DT=0.030+CFG FAIL  (ETA 13193s)
#   [2512/50000] 2507/50000 L=600.0+H=15+V=20+LV=0.5+Y=1.0+RS=1.25+WDA=0.025+HZ=20+DT=0.030+CFG FAIL  (ETA 13193s)
#   [2513/50000] 2518/50000 L=600.0+H=15+V=20+LV=0.5+Y=1.0+RS=2.0+WDA=0.02+HZ=20+DT=0.030+CFG FAIL  (ETA 13188s)
#   [2514/50000] 2514/50000 L=600.0+H=15+V=20+LV=0.5+Y=1.0+RS=1.75+WDA=0.02+HZ=20+DT=0.030+CFG FAIL  (ETA 13184s)
#   [2515/50000] 2513/50000 L=600.0+H=15+V=20+LV=0.5+Y=1.0+RS=1.75+WDA=0.015+HZ=20+DT=0.030+CFG FAIL  (ETA 13179s)
#   [2516/50000] 2515/50000 L=600.0+H=15+V=20+LV=0.5+Y=1.0+RS=1.75+WDA=0.025+HZ=20+DT=0.030+CFG FAIL  (ETA 13176s)
#   [2517/50000] 2519/50000 L=600.0+H=15+V=20+LV=0.5+Y=1.0+RS=2.0+WDA=0.025+HZ=20+DT=0.030+CFG FAIL  (ETA 13187s)
#   [2518/50000] 2523/50000 L=600.0+H=15+V=20+LV=0.5+Y=1.25+RS=1.0+WDA=0.025+HZ=20+DT=0.030+CFG FAIL  (ETA 13188s)
#   [2519/50000] 2521/50000 L=600.0+H=15+V=20+LV=0.5+Y=1.25+RS=1.0+WDA=0.015+HZ=20+DT=0.030+CFG FAIL  (ETA 13194s)
#   [2520/50000] 2517/50000 L=600.0+H=15+V=20+LV=0.5+Y=1.0+RS=2.0+WDA=0.015+HZ=20+DT=0.030+CFG FAIL  (ETA 13190s)
#   [2521/50000] 2528/50000 L=600.0+H=15+V=20+LV=0.5+Y=1.25+RS=1.25+WDA=0.03+HZ=20+DT=0.030+CFG FAIL  (ETA 13188s)
#   [2522/50000] 2530/50000 L=600.0+H=15+V=20+LV=0.5+Y=1.25+RS=1.5+WDA=0.02+HZ=20+DT=0.030+CFG FAIL  (ETA 13186s)
#   [2523/50000] 2527/50000 L=600.0+H=15+V=20+LV=0.5+Y=1.25+RS=1.25+WDA=0.025+HZ=20+DT=0.030+CFG FAIL  (ETA 13184s)
#   [2524/50000] 2525/50000 L=600.0+H=15+V=20+LV=0.5+Y=1.25+RS=1.25+WDA=0.015+HZ=20+DT=0.030+CFG FAIL  (ETA 13179s)
#   [2525/50000] 2520/50000 L=600.0+H=15+V=20+LV=0.5+Y=1.0+RS=2.0+WDA=0.03+HZ=20+DT=0.030+CFG FAIL  (ETA 13178s)
#   [2526/50000] 2526/50000 L=600.0+H=15+V=20+LV=0.5+Y=1.25+RS=1.25+WDA=0.02+HZ=20+DT=0.030+CFG FAIL  (ETA 13178s)
#   [2527/50000] 2532/50000 L=600.0+H=15+V=20+LV=0.5+Y=1.25+RS=1.5+WDA=0.03+HZ=20+DT=0.030+CFG FAIL  (ETA 13176s)
#   [2528/50000] 2533/50000 L=600.0+H=15+V=20+LV=0.5+Y=1.25+RS=1.75+WDA=0.015+HZ=20+DT=0.030+CFG FAIL  (ETA 13173s)
#   [2529/50000] 2522/50000 L=600.0+H=15+V=20+LV=0.5+Y=1.25+RS=1.0+WDA=0.02+HZ=20+DT=0.030+CFG FAIL  (ETA 13172s)
#   [2530/50000] 2537/50000 L=600.0+H=15+V=20+LV=0.5+Y=1.25+RS=2.0+WDA=0.015+HZ=20+DT=0.030+CFG FAIL  (ETA 13173s)
#   [2531/50000] 2531/50000 L=600.0+H=15+V=20+LV=0.5+Y=1.25+RS=1.5+WDA=0.025+HZ=20+DT=0.030+CFG FAIL  (ETA 13170s)
#   [2532/50000] 2524/50000 L=600.0+H=15+V=20+LV=0.5+Y=1.25+RS=1.0+WDA=0.03+HZ=20+DT=0.030+CFG FAIL  (ETA 13168s)
#   [2533/50000] 2536/50000 L=600.0+H=15+V=20+LV=0.5+Y=1.25+RS=1.75+WDA=0.03+HZ=20+DT=0.030+CFG FAIL  (ETA 13166s)
#   [2534/50000] 2529/50000 L=600.0+H=15+V=20+LV=0.5+Y=1.25+RS=1.5+WDA=0.015+HZ=20+DT=0.030+CFG FAIL  (ETA 13163s)
#   [2535/50000] 2535/50000 L=600.0+H=15+V=20+LV=0.5+Y=1.25+RS=1.75+WDA=0.025+HZ=20+DT=0.030+CFG FAIL  (ETA 13163s)
#   [2536/50000] 2542/50000 L=600.0+H=15+V=20+LV=0.5+Y=1.5+RS=1.0+WDA=0.02+HZ=20+DT=0.030+CFG FAIL  (ETA 13157s)
#   [2537/50000] 2539/50000 L=600.0+H=15+V=20+LV=0.5+Y=1.25+RS=2.0+WDA=0.025+HZ=20+DT=0.030+CFG FAIL  (ETA 13154s)
#   [2538/50000] 2534/50000 L=600.0+H=15+V=20+LV=0.5+Y=1.25+RS=1.75+WDA=0.02+HZ=20+DT=0.030+CFG FAIL  (ETA 13149s)
#   [2539/50000] 2541/50000 L=600.0+H=15+V=20+LV=0.5+Y=1.5+RS=1.0+WDA=0.015+HZ=20+DT=0.030+CFG FAIL  (ETA 13150s)
#   [2540/50000] 2538/50000 L=600.0+H=15+V=20+LV=0.5+Y=1.25+RS=2.0+WDA=0.02+HZ=20+DT=0.030+CFG FAIL  (ETA 13148s)
#   [2541/50000] 2540/50000 L=600.0+H=15+V=20+LV=0.5+Y=1.25+RS=2.0+WDA=0.03+HZ=20+DT=0.030+CFG FAIL  (ETA 13145s)
#   [2542/50000] 2543/50000 L=600.0+H=15+V=20+LV=0.5+Y=1.5+RS=1.0+WDA=0.025+HZ=20+DT=0.030+CFG FAIL  (ETA 13152s)
#   [2543/50000] 2548/50000 L=600.0+H=15+V=20+LV=0.5+Y=1.5+RS=1.25+WDA=0.03+HZ=20+DT=0.030+CFG FAIL  (ETA 13155s)
#   [2544/50000] 2545/50000 L=600.0+H=15+V=20+LV=0.5+Y=1.5+RS=1.25+WDA=0.015+HZ=20+DT=0.030+CFG FAIL  (ETA 13150s)
#   [2545/50000] 2544/50000 L=600.0+H=15+V=20+LV=0.5+Y=1.5+RS=1.0+WDA=0.03+HZ=20+DT=0.030+CFG FAIL  (ETA 13145s)
#   [2546/50000] 2547/50000 L=600.0+H=15+V=20+LV=0.5+Y=1.5+RS=1.25+WDA=0.025+HZ=20+DT=0.030+CFG FAIL  (ETA 13141s)
#   [2547/50000] 2550/50000 L=600.0+H=15+V=20+LV=0.5+Y=1.5+RS=1.5+WDA=0.02+HZ=20+DT=0.030+CFG FAIL  (ETA 13143s)
#   [2548/50000] 2549/50000 L=600.0+H=15+V=20+LV=0.5+Y=1.5+RS=1.5+WDA=0.015+HZ=20+DT=0.030+CFG FAIL  (ETA 13138s)
#   [2549/50000] 2546/50000 L=600.0+H=15+V=20+LV=0.5+Y=1.5+RS=1.25+WDA=0.02+HZ=20+DT=0.030+CFG FAIL  (ETA 13134s)
#   [2550/50000] 2554/50000 L=600.0+H=15+V=20+LV=0.5+Y=1.5+RS=1.75+WDA=0.02+HZ=20+DT=0.030+CFG FAIL  (ETA 13135s)
#   [2551/50000] 2557/50000 L=600.0+H=15+V=20+LV=0.5+Y=1.5+RS=2.0+WDA=0.015+HZ=20+DT=0.030+CFG FAIL  (ETA 13130s)
#   [2552/50000] 2553/50000 L=600.0+H=15+V=20+LV=0.5+Y=1.5+RS=1.75+WDA=0.015+HZ=20+DT=0.030+CFG FAIL  (ETA 13125s)
#   [2553/50000] 2551/50000 L=600.0+H=15+V=20+LV=0.5+Y=1.5+RS=1.5+WDA=0.025+HZ=20+DT=0.030+CFG FAIL  (ETA 13120s)
#   [2554/50000] 2510/50000 L=600.0+H=15+V=20+LV=0.5+Y=1.0+RS=1.5+WDA=0.02+HZ=20+DT=0.030+CFG FAIL  (ETA 13116s)
#   [2555/50000] 2552/50000 L=600.0+H=15+V=20+LV=0.5+Y=1.5+RS=1.5+WDA=0.03+HZ=20+DT=0.030+CFG FAIL  (ETA 13112s)
#   [2556/50000] 2555/50000 L=600.0+H=15+V=20+LV=0.5+Y=1.5+RS=1.75+WDA=0.025+HZ=20+DT=0.030+CFG FAIL  (ETA 13114s)
#   [2557/50000] 2559/50000 L=600.0+H=15+V=20+LV=0.5+Y=1.5+RS=2.0+WDA=0.025+HZ=20+DT=0.030+CFG FAIL  (ETA 13110s)
#   [2558/50000] 2560/50000 L=600.0+H=15+V=20+LV=0.5+Y=1.5+RS=2.0+WDA=0.03+HZ=20+DT=0.030+CFG FAIL  (ETA 13107s)
#   [2559/50000] 2561/50000 L=600.0+H=15+V=20+LV=0.5+Y=1.75+RS=1.0+WDA=0.015+HZ=20+DT=0.030+CFG FAIL  (ETA 13102s)
#   [2560/50000] 2556/50000 L=600.0+H=15+V=20+LV=0.5+Y=1.5+RS=1.75+WDA=0.03+HZ=20+DT=0.030+CFG FAIL  (ETA 13098s)
#   [2561/50000] 2564/50000 L=600.0+H=15+V=20+LV=0.5+Y=1.75+RS=1.0+WDA=0.03+HZ=20+DT=0.030+CFG FAIL  (ETA 13099s)
#   [2562/50000] 2563/50000 L=600.0+H=15+V=20+LV=0.5+Y=1.75+RS=1.0+WDA=0.025+HZ=20+DT=0.030+CFG FAIL  (ETA 13096s)
#   [2563/50000] 2573/50000 L=600.0+H=15+V=20+LV=0.5+Y=1.75+RS=1.75+WDA=0.015+HZ=20+DT=0.030+CFG FAIL  (ETA 13097s)
#   [2564/50000] 2558/50000 L=600.0+H=15+V=20+LV=0.5+Y=1.5+RS=2.0+WDA=0.02+HZ=20+DT=0.030+CFG FAIL  (ETA 13100s)
#   [2565/50000] 2562/50000 L=600.0+H=15+V=20+LV=0.5+Y=1.75+RS=1.0+WDA=0.02+HZ=20+DT=0.030+CFG FAIL  (ETA 13095s)
#   [2566/50000] 2567/50000 L=600.0+H=15+V=20+LV=0.5+Y=1.75+RS=1.25+WDA=0.025+HZ=20+DT=0.030+CFG FAIL  (ETA 13094s)
#   [2567/50000] 2566/50000 L=600.0+H=15+V=20+LV=0.5+Y=1.75+RS=1.25+WDA=0.02+HZ=20+DT=0.030+CFG FAIL  (ETA 13108s)
#   [2568/50000] 2576/50000 L=600.0+H=15+V=20+LV=0.5+Y=1.75+RS=1.75+WDA=0.03+HZ=20+DT=0.030+CFG FAIL  (ETA 13106s)
#   [2569/50000] 2570/50000 L=600.0+H=15+V=20+LV=0.5+Y=1.75+RS=1.5+WDA=0.02+HZ=20+DT=0.030+CFG FAIL  (ETA 13103s)
#   [2570/50000] 2565/50000 L=600.0+H=15+V=20+LV=0.5+Y=1.75+RS=1.25+WDA=0.015+HZ=20+DT=0.030+CFG FAIL  (ETA 13099s)
#   [2571/50000] 2580/50000 L=600.0+H=15+V=20+LV=0.5+Y=1.75+RS=2.0+WDA=0.03+HZ=20+DT=0.030+CFG FAIL  (ETA 13095s)
#   [2572/50000] 2572/50000 L=600.0+H=15+V=20+LV=0.5+Y=1.75+RS=1.5+WDA=0.03+HZ=20+DT=0.030+CFG FAIL  (ETA 13093s)
#   [2573/50000] 2574/50000 L=600.0+H=15+V=20+LV=0.5+Y=1.75+RS=1.75+WDA=0.02+HZ=20+DT=0.030+CFG FAIL  (ETA 13089s)
#   [2574/50000] 2568/50000 L=600.0+H=15+V=20+LV=0.5+Y=1.75+RS=1.25+WDA=0.03+HZ=20+DT=0.030+CFG FAIL  (ETA 13090s)
#   [2575/50000] 2575/50000 L=600.0+H=15+V=20+LV=0.5+Y=1.75+RS=1.75+WDA=0.025+HZ=20+DT=0.030+CFG FAIL  (ETA 13086s)
#   [2576/50000] 2569/50000 L=600.0+H=15+V=20+LV=0.5+Y=1.75+RS=1.5+WDA=0.015+HZ=20+DT=0.030+CFG FAIL  (ETA 13083s)
#   [2577/50000] 2579/50000 L=600.0+H=15+V=20+LV=0.5+Y=1.75+RS=2.0+WDA=0.025+HZ=20+DT=0.030+CFG FAIL  (ETA 13079s)
#   [2578/50000] 2578/50000 L=600.0+H=15+V=20+LV=0.5+Y=1.75+RS=2.0+WDA=0.02+HZ=20+DT=0.030+CFG FAIL  (ETA 13076s)
#   [2579/50000] 2581/50000 L=600.0+H=15+V=20+LV=0.5+Y=2.0+RS=1.0+WDA=0.015+HZ=20+DT=0.030+CFG FAIL  (ETA 13076s)
#   [2580/50000] 2577/50000 L=600.0+H=15+V=20+LV=0.5+Y=1.75+RS=2.0+WDA=0.015+HZ=20+DT=0.030+CFG FAIL  (ETA 13073s)
#   [2581/50000] 2583/50000 L=600.0+H=15+V=20+LV=0.5+Y=2.0+RS=1.0+WDA=0.025+HZ=20+DT=0.030+CFG FAIL  (ETA 13078s)
#   [2582/50000] 2571/50000 L=600.0+H=15+V=20+LV=0.5+Y=1.75+RS=1.5+WDA=0.025+HZ=20+DT=0.030+CFG FAIL  (ETA 13075s)
#   [2583/50000] 2586/50000 L=600.0+H=15+V=20+LV=0.5+Y=2.0+RS=1.25+WDA=0.02+HZ=20+DT=0.030+CFG FAIL  (ETA 13070s)
#   [2584/50000] 2589/50000 L=600.0+H=15+V=20+LV=0.5+Y=2.0+RS=1.5+WDA=0.015+HZ=20+DT=0.030+CFG FAIL  (ETA 13065s)
#   [2585/50000] 2590/50000 L=600.0+H=15+V=20+LV=0.5+Y=2.0+RS=1.5+WDA=0.02+HZ=20+DT=0.030+CFG FAIL  (ETA 13062s)
#   [2586/50000] 2592/50000 L=600.0+H=15+V=20+LV=0.5+Y=2.0+RS=1.5+WDA=0.03+HZ=20+DT=0.030+CFG FAIL  (ETA 13060s)
#   [2587/50000] 2588/50000 L=600.0+H=15+V=20+LV=0.5+Y=2.0+RS=1.25+WDA=0.03+HZ=20+DT=0.030+CFG FAIL  (ETA 13057s)
#   [2588/50000] 2591/50000 L=600.0+H=15+V=20+LV=0.5+Y=2.0+RS=1.5+WDA=0.025+HZ=20+DT=0.030+CFG FAIL  (ETA 13054s)
#   [2589/50000] 2582/50000 L=600.0+H=15+V=20+LV=0.5+Y=2.0+RS=1.0+WDA=0.02+HZ=20+DT=0.030+CFG FAIL  (ETA 13050s)
#   [2590/50000] 2587/50000 L=600.0+H=15+V=20+LV=0.5+Y=2.0+RS=1.25+WDA=0.025+HZ=20+DT=0.030+CFG FAIL  (ETA 13059s)
#   [2591/50000] 2594/50000 L=600.0+H=15+V=20+LV=0.5+Y=2.0+RS=1.75+WDA=0.02+HZ=20+DT=0.030+CFG FAIL  (ETA 13055s)
#   [2592/50000] 2584/50000 L=600.0+H=15+V=20+LV=0.5+Y=2.0+RS=1.0+WDA=0.03+HZ=20+DT=0.030+CFG FAIL  (ETA 13050s)
#   [2593/50000] 2585/50000 L=600.0+H=15+V=20+LV=0.5+Y=2.0+RS=1.25+WDA=0.015+HZ=20+DT=0.030+CFG FAIL  (ETA 13046s)
#   [2594/50000] 2598/50000 L=600.0+H=15+V=20+LV=0.5+Y=2.0+RS=2.0+WDA=0.02+HZ=20+DT=0.030+CFG FAIL  (ETA 13042s)
#   [2595/50000] 2597/50000 L=600.0+H=15+V=20+LV=0.5+Y=2.0+RS=2.0+WDA=0.015+HZ=20+DT=0.030+CFG FAIL  (ETA 13038s)
#   [2596/50000] 2595/50000 L=600.0+H=15+V=20+LV=0.5+Y=2.0+RS=1.75+WDA=0.025+HZ=20+DT=0.030+CFG FAIL  (ETA 13044s)
#   [2597/50000] 2596/50000 L=600.0+H=15+V=20+LV=0.5+Y=2.0+RS=1.75+WDA=0.03+HZ=20+DT=0.030+CFG FAIL  (ETA 13048s)
#   [2598/50000] 2593/50000 L=600.0+H=15+V=20+LV=0.5+Y=2.0+RS=1.75+WDA=0.015+HZ=20+DT=0.030+CFG FAIL  (ETA 13043s)
#   [2599/50000] 2599/50000 L=600.0+H=15+V=20+LV=0.5+Y=2.0+RS=2.0+WDA=0.025+HZ=20+DT=0.030+CFG FAIL  (ETA 13047s)
#   [2600/50000] 2604/50000 L=600.0+H=15+V=20+LV=0.75+Y=1.0+RS=1.0+WDA=0.03+HZ=20+DT=0.030+CFG FAIL  (ETA 13042s)
#   [2601/50000] 2603/50000 L=600.0+H=15+V=20+LV=0.75+Y=1.0+RS=1.0+WDA=0.025+HZ=20+DT=0.030+CFG FAIL  (ETA 13053s)
#   [2602/50000] 2609/50000 L=600.0+H=15+V=20+LV=0.75+Y=1.0+RS=1.5+WDA=0.015+HZ=20+DT=0.030+CFG FAIL  (ETA 13050s)
#   [2603/50000] 2601/50000 L=600.0+H=15+V=20+LV=0.75+Y=1.0+RS=1.0+WDA=0.015+HZ=20+DT=0.030+CFG FAIL  (ETA 13048s)
#   [2604/50000] 2602/50000 L=600.0+H=15+V=20+LV=0.75+Y=1.0+RS=1.0+WDA=0.02+HZ=20+DT=0.030+CFG FAIL  (ETA 13045s)
#   [2605/50000] 2600/50000 L=600.0+H=15+V=20+LV=0.5+Y=2.0+RS=2.0+WDA=0.03+HZ=20+DT=0.030+CFG FAIL  (ETA 13043s)
#   [2606/50000] 2605/50000 L=600.0+H=15+V=20+LV=0.75+Y=1.0+RS=1.25+WDA=0.015+HZ=20+DT=0.030+CFG FAIL  (ETA 13041s)
#   [2607/50000] 2611/50000 L=600.0+H=15+V=20+LV=0.75+Y=1.0+RS=1.5+WDA=0.025+HZ=20+DT=0.030+CFG FAIL  (ETA 13037s)
#   [2608/50000] 2610/50000 L=600.0+H=15+V=20+LV=0.75+Y=1.0+RS=1.5+WDA=0.02+HZ=20+DT=0.030+CFG FAIL  (ETA 13033s)
#   [2609/50000] 2608/50000 L=600.0+H=15+V=20+LV=0.75+Y=1.0+RS=1.25+WDA=0.03+HZ=20+DT=0.030+CFG FAIL  (ETA 13030s)
#   [2610/50000] 2615/50000 L=600.0+H=15+V=20+LV=0.75+Y=1.0+RS=1.75+WDA=0.025+HZ=20+DT=0.030+CFG FAIL  (ETA 13034s)
#   [2611/50000] 2607/50000 L=600.0+H=15+V=20+LV=0.75+Y=1.0+RS=1.25+WDA=0.025+HZ=20+DT=0.030+CFG FAIL  (ETA 13031s)
#   [2612/50000] 2612/50000 L=600.0+H=15+V=20+LV=0.75+Y=1.0+RS=1.5+WDA=0.03+HZ=20+DT=0.030+CFG FAIL  (ETA 13027s)
#   [2613/50000] 2618/50000 L=600.0+H=15+V=20+LV=0.75+Y=1.0+RS=2.0+WDA=0.02+HZ=20+DT=0.030+CFG FAIL  (ETA 13024s)
#   [2614/50000] 2619/50000 L=600.0+H=15+V=20+LV=0.75+Y=1.0+RS=2.0+WDA=0.025+HZ=20+DT=0.030+CFG FAIL  (ETA 13034s)
#   [2615/50000] 2617/50000 L=600.0+H=15+V=20+LV=0.75+Y=1.0+RS=2.0+WDA=0.015+HZ=20+DT=0.030+CFG FAIL  (ETA 13038s)
#   [2616/50000] 2622/50000 L=600.0+H=15+V=20+LV=0.75+Y=1.25+RS=1.0+WDA=0.02+HZ=20+DT=0.030+CFG FAIL  (ETA 13043s)
#   [2617/50000] 2626/50000 L=600.0+H=15+V=20+LV=0.75+Y=1.25+RS=1.25+WDA=0.02+HZ=20+DT=0.030+CFG FAIL  (ETA 13048s)
#   [2618/50000] 2621/50000 L=600.0+H=15+V=20+LV=0.75+Y=1.25+RS=1.0+WDA=0.015+HZ=20+DT=0.030+CFG FAIL  (ETA 13044s)
#   [2619/50000] 2620/50000 L=600.0+H=15+V=20+LV=0.75+Y=1.0+RS=2.0+WDA=0.03+HZ=20+DT=0.030+CFG FAIL  (ETA 13039s)
#   [2620/50000] 2606/50000 L=600.0+H=15+V=20+LV=0.75+Y=1.0+RS=1.25+WDA=0.02+HZ=20+DT=0.030+CFG FAIL  (ETA 13037s)
#   [2621/50000] 2628/50000 L=600.0+H=15+V=20+LV=0.75+Y=1.25+RS=1.25+WDA=0.03+HZ=20+DT=0.030+CFG FAIL  (ETA 13034s)
#   [2622/50000] 2614/50000 L=600.0+H=15+V=20+LV=0.75+Y=1.0+RS=1.75+WDA=0.02+HZ=20+DT=0.030+CFG FAIL  (ETA 13029s)
#   [2623/50000] 2616/50000 L=600.0+H=15+V=20+LV=0.75+Y=1.0+RS=1.75+WDA=0.03+HZ=20+DT=0.030+CFG FAIL  (ETA 13024s)
#   [2624/50000] 2630/50000 L=600.0+H=15+V=20+LV=0.75+Y=1.25+RS=1.5+WDA=0.02+HZ=20+DT=0.030+CFG FAIL  (ETA 13029s)
#   [2625/50000] 2624/50000 L=600.0+H=15+V=20+LV=0.75+Y=1.25+RS=1.0+WDA=0.03+HZ=20+DT=0.030+CFG FAIL  (ETA 13029s)
#   [2626/50000] 2613/50000 L=600.0+H=15+V=20+LV=0.75+Y=1.0+RS=1.75+WDA=0.015+HZ=20+DT=0.030+CFG FAIL  (ETA 13024s)
#   [2627/50000] 2627/50000 L=600.0+H=15+V=20+LV=0.75+Y=1.25+RS=1.25+WDA=0.025+HZ=20+DT=0.030+CFG FAIL  (ETA 13023s)
#   [2628/50000] 2625/50000 L=600.0+H=15+V=20+LV=0.75+Y=1.25+RS=1.25+WDA=0.015+HZ=20+DT=0.030+CFG FAIL  (ETA 13020s)
#   [2629/50000] 2629/50000 L=600.0+H=15+V=20+LV=0.75+Y=1.25+RS=1.5+WDA=0.015+HZ=20+DT=0.030+CFG FAIL  (ETA 13023s)
#   [2630/50000] 2623/50000 L=600.0+H=15+V=20+LV=0.75+Y=1.25+RS=1.0+WDA=0.025+HZ=20+DT=0.030+CFG FAIL  (ETA 13035s)
#   [2631/50000] 2638/50000 L=600.0+H=15+V=20+LV=0.75+Y=1.25+RS=2.0+WDA=0.02+HZ=20+DT=0.030+CFG FAIL  (ETA 13036s)
#   [2632/50000] 2640/50000 L=600.0+H=15+V=20+LV=0.75+Y=1.25+RS=2.0+WDA=0.03+HZ=20+DT=0.030+CFG FAIL  (ETA 13033s)
#   [2633/50000] 2631/50000 L=600.0+H=15+V=20+LV=0.75+Y=1.25+RS=1.5+WDA=0.025+HZ=20+DT=0.030+CFG FAIL  (ETA 13029s)
#   [2634/50000] 2637/50000 L=600.0+H=15+V=20+LV=0.75+Y=1.25+RS=2.0+WDA=0.015+HZ=20+DT=0.030+CFG FAIL  (ETA 13031s)
#   [2635/50000] 2635/50000 L=600.0+H=15+V=20+LV=0.75+Y=1.25+RS=1.75+WDA=0.025+HZ=20+DT=0.030+CFG FAIL  (ETA 13027s)
#   [2636/50000] 2633/50000 L=600.0+H=15+V=20+LV=0.75+Y=1.25+RS=1.75+WDA=0.015+HZ=20+DT=0.030+CFG FAIL  (ETA 13033s)
#   [2637/50000] 2646/50000 L=600.0+H=15+V=20+LV=0.75+Y=1.5+RS=1.25+WDA=0.02+HZ=20+DT=0.030+CFG FAIL  (ETA 13034s)
#   [2638/50000] 2636/50000 L=600.0+H=15+V=20+LV=0.75+Y=1.25+RS=1.75+WDA=0.03+HZ=20+DT=0.030+CFG FAIL  (ETA 13029s)
#   [2639/50000] 2632/50000 L=600.0+H=15+V=20+LV=0.75+Y=1.25+RS=1.5+WDA=0.03+HZ=20+DT=0.030+CFG FAIL  (ETA 13025s)
#   [2640/50000] 2647/50000 L=600.0+H=15+V=20+LV=0.75+Y=1.5+RS=1.25+WDA=0.025+HZ=20+DT=0.030+CFG FAIL  (ETA 13023s)
#   [2641/50000] 2634/50000 L=600.0+H=15+V=20+LV=0.75+Y=1.25+RS=1.75+WDA=0.02+HZ=20+DT=0.030+CFG FAIL  (ETA 13017s)
#   [2642/50000] 2642/50000 L=600.0+H=15+V=20+LV=0.75+Y=1.5+RS=1.0+WDA=0.02+HZ=20+DT=0.030+CFG FAIL  (ETA 13015s)
#   [2643/50000] 2641/50000 L=600.0+H=15+V=20+LV=0.75+Y=1.5+RS=1.0+WDA=0.015+HZ=20+DT=0.030+CFG FAIL  (ETA 13011s)
#   [2644/50000] 2643/50000 L=600.0+H=15+V=20+LV=0.75+Y=1.5+RS=1.0+WDA=0.025+HZ=20+DT=0.030+CFG FAIL  (ETA 13019s)
#   [2645/50000] 2645/50000 L=600.0+H=15+V=20+LV=0.75+Y=1.5+RS=1.25+WDA=0.015+HZ=20+DT=0.030+CFG FAIL  (ETA 13015s)
#   [2646/50000] 2650/50000 L=600.0+H=15+V=20+LV=0.75+Y=1.5+RS=1.5+WDA=0.02+HZ=20+DT=0.030+CFG FAIL  (ETA 13014s)
#   [2647/50000] 2644/50000 L=600.0+H=15+V=20+LV=0.75+Y=1.5+RS=1.0+WDA=0.03+HZ=20+DT=0.030+CFG FAIL  (ETA 13011s)
#   [2648/50000] 2648/50000 L=600.0+H=15+V=20+LV=0.75+Y=1.5+RS=1.25+WDA=0.03+HZ=20+DT=0.030+CFG FAIL  (ETA 13007s)

# %%
# Show latest output files.
out_dir = MPC_DIR / "test"
latest_csv = sorted(out_dir.glob("tuning_hardware_base_*.csv"), key=lambda p: p.stat().st_mtime, reverse=True)[:5]
latest_sorted = sorted(out_dir.glob("tuning_hardware_base_*_sorted.csv"), key=lambda p: p.stat().st_mtime, reverse=True)[:5]

print("Latest CSV files:")
for p in latest_csv:
    print(" ", p.name)

print("\nLatest sorted CSV files:")
for p in latest_sorted:
    print(" ", p.name)
# Out:
# Latest CSV files:
#   tuning_hardware_base_20260429_202200_sorted_continued_20260430_123417_sorted.csv
#   tuning_hardware_base_20260429_202200_sorted_continued_20260430_123417.csv
#   tuning_hardware_base_20260429_202200_sorted_continued_20260430_120400.csv
#   tuning_hardware_base_20260429_202200_sorted.csv
#   tuning_hardware_base_20260429_202200.csv
#
# Latest sorted CSV files:
#   tuning_hardware_base_20260429_202200_sorted_continued_20260430_123417_sorted.csv
#   tuning_hardware_base_20260429_202200_sorted.csv
